# %% [markdown]
# # Tutorial: Working with Text
#
# ## Guggenheim Museum Art Books
#
# This tutorial on how to work with Text in Python. In order to run the example, we will leverage art books made publicly available by Guggenheim Museum. The full reporistory of books is available here: https://archive.org/details/guggenheimmuseum?and%5B%5D=mediatype%3A%22texts%22&sort=titleSorter&page=1
# The txt format of this has been split into multiple files, one book per file.
# The data can be found in ../data/books/{1, 2, ..., 220}.txt
# There are 207 art books

# %% [markdown]
# ## Step 1: Load the data
#
# Firstly, let's read the book and ensure proper encoding of the document.
# Please select the book that you want to load:
#    * Open the ../data/book_list.csv
#    * Select the book you are interested to work with (e.g. "Marc Chagall and the Jewish theater"
#    * Find the corresponding book_urn (e.g. "chagallj00chag")
#    * Create a url by replacing book urn in the following url https://raw.githubusercontent.com/AnnaNican/wcaiconf_2019/master/data/books/[your book].txt
#    (e.g. https://raw.githubusercontent.com/AnnaNican/wcaiconf_2019/master/data/books/chagallj00chag.txt )
#    * Place the url below in the file url

# %%
import urllib2

fileurl = 'https://raw.githubusercontent.com/AnnaNican/wcaiconf_2019/master/data/books/chagallj00chag.txt'
booktext = urllib2.urlopen(fileurl).read()

booktext = booktext.replace('\n', '')
booktext = unicode(booktext, 'utf-8')

print(booktext)
# Out:
# GUGGENHEIM MUSEUM Digitized by the Internet Arciiive in 2012 witii funding from IVIetropolitan New York Library Council - METRO http://archive.org/details/chagalljOOchag Marc Chagall and the Jevs^ish Theater Marc Chagall and the JevN^ish Theater GUGGENHEIM MUSEUM ©The Solomon R. Guggenheim Foundation, New York, 1992 All rights reserved Reproductions of cat. nos. 1-7 © State Tret'iakov Gallery, Moscow Marc Chagall and the Je&gt;vish Theater Solomon R. Guggenheim Museum September 23, 1992-January 17, 1993 The Art Institute of Chicago January 30-May 7, 1993 ISBN: 0-89207-099-4 Published by the Guggenheim Museum 1071 Fifth Avenue New York, New York 10128 Prmted m the United States by Thorner Press Front cover: Marc Chagall, M/isk, 1920 Tempera and gouache on canvas 212.4 ^ I03-5 cm (83 V« X 40 V4 inches) State Tret'iakov Gallery, Moscow Back cover: Marc Chagall, Loi'e on the Stage. 1920 Tempera and gouache on canvas 284.2 X 249.6 cm (in 7s x 98 'A inches) State Tret'iakov Gallery, Moscow Frontispiece: Emblem of the Jewish Chamber Theater, taken from a 1919 poster printed in Petrograd. Color photography: Cat. nos. 1-7, from State Tret'iakov Gallery, Moscow; nos. I, 2 photo H. Preisig; no. 3 courtesy Fondation Pierre Gianadda; nos. 4-7 photographed by Lee Ewing. Cat. nos. 8, 9, 11, 14, from Musee national d'art moderne. Centre Georges Pompidou, Paris; photo Philippe Migeat, © Centre G. Pompidou. Cat. nos. 10, 12, 13, 15-20, from the collection of Ida Chagall, Paris. Cat. nos. 21—32, from Solomon R. Guggenheim Museum; no. 24 photographed by Myles Aronowitz; no. 29 by Lee Ewing; nos. 21, 31, 32 by Carmelo Guadagno; nos. 21-23, 2.5—28, 30 by David Heald. This exhibition has been sponsored, in part, by Lufthansa German Airlines. Lufthansa Additional support has been provided by The Helena Rubinstein Foundation. Marc Chagall and the Jewish Theater Contents Preface Thomas Krens viii Fore&gt;vord h/rii K. Korolev X Sponsor's Statement jiirgm Weber xi Introduction Jeiuujer Bleising xii Chagall's Auditorium: "An Identity Crisis of Tragic Dimensions' S/i.saii C ODiptoii I Chagall: Postmodernism and Fictional Worlds in Painting Benjamin Harshav 15 Catalogue to the Exhibition 65 Texts and Documents Edited by Benjamin Harshav Translated by Benjamin and Barbara Harshav 133 Bibliography Benjamin Harshav 200 Aftervs^ord Gregory Veitsman 205 Alan- Chagall and the Jewish Theater appears at the Gu^'genheim Museum SoHo while The Great Utopia: The R/issian and Soviet Avant-Garde, ipi$-ip^2, the comprehensive exhibition of one of the principal Modernist movements of the twentieth century, is on display at the Solomon R. Guggenheim Museum. The Great Utopia presents the fruits ot the avant-garde's attempt to restructure an entire society — economically, socially, and culturally — in the face of a tremendous political upheaval, the Russian Revolution. Artists became integral participants in the formation ol the Soviet government. They also strove to create new forms for art and utilitarian objects that would function purposefully to bring about and encourage change. Stranded in Russia during a visit with his fiancee before World War I, Marc Chagall participated in revolutionary debates about art and politics. He was appointed the Commissar of Art for the region of Vitebsk and founded an art academy and museum in his official capacity. At the academy, Chagall's teachings were challenged by Kazimir Malevich, who succeeded in convincing the school's students of the primacy of his Suprematism. The Great Utopia serves as an excellent background for Marc Chagall and the Jewish Theater by providing the context within which Chagall, in 1920, undertook his commission for the State Jewish Chamber Theater. Marc Chagall and the Jewish Theater, in turn, can be viewed as a counterpoint to The Great Utopia in that it presents the work of an artist whose methods of representation, enigmatic symbolism, and abstract individualist ideology left him at odds with many of his fe ...

# %% [markdown]
# # Step 2: Exploring the data

# %% [markdown]
# ##  Tokenisation
#
# Given a character sequence and a defined document unit, tokenization is the task of chopping it up into pieces, called tokens , perhaps at the same time throwing away certain characters, such as punctuation. In short, "token" is a meaningful units of text
#
# * Words
# * Phrases
# * Punctuation
# * Numbers
# * Dates
# * Currencies
# * Hashtags
# * ...?
#
#
# These tokens are often loosely referred to as terms or words, but it is sometimes important to make a type/token distinction. A token is an instance of a sequence of characters in some particular document that are grouped together as a useful semantic unit for processing.

# %%
from nltk.tokenize import word_tokenize

try:  # py3
    all_tokens = [t for t in word_tokenize(booktext)]
except UnicodeDecodeError:  # py27
#     all_tokens = [t for t in word_tokenize(corpus_all_in_one.decode('utf-8'))]
    all_tokens = [t for t in word_tokenize(booktext.decode('utf-8'))]

print("Total number of tokens: {}".format(len(booktext)))
print("Sample of tokens: {}".format(booktext[0:10]))
# Out:
# Total number of tokens: 687938
# Sample of tokens: GUGGENHEIM

# %% [markdown]
# ## Counting Words¶
#
# We start with a simple word count using **collections.Counter**
# We are interested in finding: how many times a word occurs across the whole corpus (total number of occurrences)

# %%
from collections import Counter

total_term_frequency = Counter(all_tokens)

for word, freq in total_term_frequency.most_common(20):
    print("{}\t{}".format(word, freq))
# Out:
# ,	9484
# the	7179
# .	6488
# of	4064
# and	3585
# in	2923
# a	2385
# to	2096
# Chagall	1197
# ``	1062
# is	1053
# 's	994
# his	973
# ''	969
# )	943
# The	919
# (	914
# was	882
# that	850
# with	831

# %% [markdown]
# ## Stop-words
#
# We notice that some of the most common words above are not very interesting.
# These words are called stop-words, and they don't provide any particular meaning in isolation (articles, conjunctions, pronouns, etc.) So we will use **nltk.corpus** to remove these words from our tokens.
#
# Notice:
# there is no "universal" list of stop-words
# removing stop-words can be useful or damaging depending on the application
# e.g. if you remove stop-words, what do you do with "The Who", "to be or not to be" and similar phrases?

# %%
from nltk.corpus import stopwords
import string

print(stopwords.words('english'))
print(len(stopwords.words('english')))
print(string.punctuation)
# Out:
# [u'i', u'me', u'my', u'myself', u'we', u'our', u'ours', u'ourselves', u'you', u'your', u'yours', u'yourself', u'yourselves', u'he', u'him', u'his', u'himself', u'she', u'her', u'hers', u'herself', u'it', u'its', u'itself', u'they', u'them', u'their', u'theirs', u'themselves', u'what', u'which', u'who', u'whom', u'this', u'that', u'these', u'those', u'am', u'is', u'are', u'was', u'were', u'be', u'been', u'being', u'have', u'has', u'had', u'having', u'do', u'does', u'did', u'doing', u'a', u'an', u'the', u'and', u'but', u'if', u'or', u'because', u'as', u'until', u'while', u'of', u'at', u'by', u'for', u'with', u'about', u'against', u'between', u'into', u'through', u'during', u'before', u'after', u'above', u'below', u'to', u'from', u'up', u'down', u'in', u'out', u'on', u'off', u'over', u'under', u'again', u'further', u'then', u'once', u'here', u'there', u'when', u'where', u'why', u'how', u'all', u'any', u'both', u'each', u'few', u'more', u'most', u'other', u'some', u'such', u'no', u'nor', u'not', u'only', u'own', u'same', u'so', u'than', u'too', u'very', u's', u't', u'can', u'will', u'just', u'don', u'should', u'now', u'd', u'll', u'm', u'o', u're', u've', u'y', u'ain', u'aren', u'couldn', u'didn', u'doesn', u'hadn', u'hasn', u'haven', u'isn', u'ma', u'mightn', u'mustn', u'needn', u'shan', u'shouldn', u'wasn', u'weren', u'won', u'wouldn']
# 153
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
stop_list = stopwords.words('english') + list(string.punctuation)

tokens_no_stop = [token for token in all_tokens
                        if token not in stop_list]

total_term_frequency_no_stop = Counter(tokens_no_stop)

for word, freq in total_term_frequency_no_stop.most_common(20):
    print("{}\t{}".format(word.encode('utf-8'), freq))
# Out:
# Chagall	1197
# ``	1062
# 's	994
# ''	969
# The	919
# I	793
# —	666
# Yiddish	592
# Jewish	563
# theater	455
# art	433
# Russian	364
# Theater	348
# In	338
# world	280
# one	266
# And	205
# Moscow	201
# new	201
# n't	200

# %% [markdown]
# ## Text Normalisation
#
# Notice, that somethimes
# Replacing tokens with a canonical form, so we can group together different spelling/variations of the same word.
# There are many ways to perform text normalization:
#
# * lowercasing
# * stemming (Stemming is the process of reducing a word to its base/root form, called stem)
#     Stemming is the process of reducing the words(generally modified or derived) to their word stem or root form. The objective of stemming is to reduce related words to the same stem even if the stem is not a dictionary word. For example, in the English language-
#
# > * beautiful and beautifully are stemmed to beauti
# > * good, better and best are stemmed to good, better and best respectively
#
#
# The original paper by Martin Porter: https://tartarus.org/martin/PorterStemmer/def.txt on Porter Algorithm for stemming.
#
# * American-to-British mapping
# * synonym mapping
# * Lemmatization (Lemmatisation is the process of reducing a group of words into their lemma or dictionary form. It takes into account things like POS(Parts of Speech), the meaning of the word in the sentence, the meaning of the word in the nearby sentences etc. before reducing the word to its lemma. For example, in the English Language-
#
# > * beautiful and beautifully are lemmatised to beautiful and beautifully respectively.
# > * good, better and best are lemmatised to good, good and good respectively.
# * ...

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
all_tokens_lower = [t.lower() for t in all_tokens]

tokens_normalised = [stemmer.stem(t) for t in all_tokens_lower
                                     if t not in stop_list]

total_term_frequency_normalised = Counter(tokens_normalised)

for word, freq in total_term_frequency_normalised.most_common(20):
    print("{}\t{}".format(word.encode('utf-8'), freq))
# Out:
# chagal	1203
# ``	1062
# 's	994
# ''	969
# theater	828
# —	666
# art	593
# yiddish	592
# jewish	568
# paint	465
# russian	368
# world	337
# artist	331
# new	327
# one	316
# work	297
# jew	222
# life	214
# time	213
# moscow	201

# %% [markdown]
# ## n-grams
# When we are interested in phrases rather than single terms, we can look into n-grams
#
# An n-gram is a sequence of n adjacent terms.
#
# Commonly used n-grams include bigrams (n=2) and trigrams (n=3).

# %%
from nltk import ngrams

phrases = Counter(ngrams(all_tokens_lower, 2))
for phrase, freq in phrases.most_common(20):
    print("{}\t{}".format(phrase, freq))
# Out:
# (u'of', u'the')	1163
# (u'in', u'the')	812
# (u',', u'and')	809
# (u',', u'the')	574
# (u'.', u'the')	504
# (u'.', u'.')	446
# (u'chagall', u"'s")	399
# (u'to', u'the')	363
# (u')', u'.')	358
# (u'and', u'the')	350
# (u'on', u'the')	330
# (u'.', u'in')	268
# (u'for', u'the')	255
# (u',', u'in')	252
# (u')', u',')	251
# (u'of', u'a')	230
# (u'.', u'i')	229
# (u',', u'a')	213
# (u'the', u'yiddish')	209
# (u'.', u"''")	204

# %%
phrases = Counter(ngrams(all_tokens_lower, 3))
for phrase, freq in phrases.most_common(20):
    print("{}\t{}".format(phrase, freq))
# Out:
# (u'.', u'.', u'.')	268
# (u',', u'and', u'the')	96
# (u'the', u'yiddish', u'theater')	96
# (u',', u'pp', u'.')	79
# (u'yiddish', u'chamber', u'theater')	70
# (u"''", u'(', u'in')	67
# (u'of', u'chagall', u"'s")	65
# (u'new', u'york', u':')	60
# (u'.', u'in', u'the')	60
# (u'.', u'chagall', u"'s")	57
# (u',', u'in', u'the')	54
# (u'the', u'jewish', u'theater')	51
# (u'of', u'the', u'yiddish')	50
# (u'texts', u'and', u'documents')	48
# (u'in', u'chagall', u"'s")	47
# (u'.', u'no', u'.')	47
# (u'the', u'yiddish', u'chamber')	46
# (u'of', u'the', u'theater')	45
# (u',', u'no', u'.')	45
# (u'marc', u'chagall', u':')	43

# %% [markdown]
# ### n-grams and stop-words
# Stop-word removal will affect n-grams
#
# e.g. phrases like "a pinch of salt" become "pinch salt" after stop-word removal

# %%
phrases = Counter(ngrams(tokens_no_stop, 2))

for phrase, freq in phrases.most_common(20):
    print("{}\t{}".format(phrase, freq))
# Out:
# (u'Chagall', u"'s")	399
# (u'Marc', u'Chagall')	137
# (u'New', u'York')	111
# (u'Chamber', u'Theater')	110
# (u'Yiddish', u'Theater')	99
# (u'Yiddish', u'theater')	81
# (u'Yiddish', u'Chamber')	70
# (u'Sholem', u'Aleichem')	70
# (u'Jewish', u'Theater')	62
# (u'``', u'The')	54
# (u'Lanternshooter', u'Menakhem-Mendel')	53
# (u'The', u'Russian')	48
# (u'Texts', u'Documents')	47
# (u'St.', u'Petersburg')	46
# (u'``', u'Chagall')	46
# (u'Chagall', u'The')	46
# (u'Granovskii', u"'s")	44
# (u"''", u'Russian')	44
# (u"''", u'Yiddish')	44
# (u"''", u'The')	42

# %%
phrases = Counter(ngrams(tokens_no_stop, 3))

for phrase, freq in phrases.most_common(20):
    print("{}\t{}".format(phrase, freq))
# Out:
# (u'Yiddish', u'Chamber', u'Theater')	70
# (u'Chagall', u'The', u'Russian')	39
# (u'The', u'Russian', u'Years')	38
# (u'Solomon', u'R.', u'Guggenheim')	31
# (u'Marc', u'Chagall', u'The')	30
# (u'Menakhem-Mendel', u'Lanternshooter', u'Menakhem-Mendel')	24
# (u'Bakingfish', u'Lanternshooter', u'Menakhem-Mendel')	24
# (u'State', u"Tret'iakov", u'Gallery')	24
# (u'Lanternshooter', u'Menakhem-Mendel', u'Lanternshooter')	23
# (u'``', u'Marc', u'Chagall')	23
# (u'Chagall', u"'s", u'art')	21
# (u'State', u'Jewish', u'Chamber')	19
# (u'Jewish', u'Chamber', u'Theater')	19
# (u'State', u'Yiddish', u'Chamber')	19
# (u'Texts', u'Documents', u'1')	18
# (u'Sholem', u'Aleichem', u'Evening')	17
# (u'R.', u'Guggenheim', u'Museum')	17
# (u'Vitali', u'Marc', u'Chagall')	17
# (u'Sholem', u'Aleichem', u"'s")	17
# (u'Chagall', u"'s", u'paintings')	17

# %% [markdown]
# ### Part of Speech Tagging
#
#
# pip install -U textblob
# python -m textblob.download_corpora
#
# Like the spaCy and NLTK libraries, the TextBlob library also contains functionalities for the POS tagging.
#
# To find POS tags for the words in a document, all you have to do is use the tags attribute as shown below:
#
# for word, pos in text_blob_object.tags:
#     print(word + " => " + pos)
# In the script above, print the tags for all the words in the first paragraph of the Wikipedia article on Artificial Intelligence. The output of the script above looks like this:

# %%
from textblob import TextBlob 
text_blob_object = TextBlob(booktext)

document_sentence = text_blob_object.sentences

# print(document_sentence)  
# print(len(document_sentence))  

for word, pos in text_blob_object.tags:  
    print(word + " => " + pos)
# Out:
# GUGGENHEIM => NNP
# MUSEUM => NNP
# Digitized => NNP
# by => IN
# the => DT
# Internet => NNP
# Arciiive => NNP
# in => IN
# 2012 => CD
# witii => NN
# funding => NN
# from => IN
# IVIetropolitan => NNP
# New => NNP
# York => NNP
# Library => NNP
# Council => NNP
# METRO => NN
# http => NN
# //archive.org/details/chagalljOOchag => JJ
# Marc => NNP
# Chagall => NNP
# and => CC
# the => DT
# Jevs^ish => NNP
# Theater => NNP
# Marc => NNP
# Chagall => NNP
# and => CC
# the => DT
# JevN^ish => NNP
# Theater => NNP
# GUGGENHEIM => NNP
# MUSEUM => NNP
# ©The => NNP
# Solomon => NNP
# R. => NNP
# Guggenheim => NNP
# Foundation => NNP
# New => NNP
# York => NNP
# 1992 => CD
# All => NNP
# rights => NNS
# reserved => VBD
# Reproductions => NNS
# of => IN
# cat => NN
# nos => NNS
# 1-7 => JJ
# © => NNP
# State => NNP
# Tret'iakov => NNP
# Gallery => NNP
# Moscow => NNP
# Marc => NNP
# Chagall => NNP
# and => CC
# the => DT
# Je => NNP
# & => CC
# gt => NN
# vish => JJ
# Theater => NNP
# Solomon => NNP
# R. => NNP
# Guggenheim => NNP
# Museum => NNP
# September => NNP
# 23 => CD
# 1992-January => JJ
# 17 => CD
# 1993 => CD
# The => DT
# Art => NNP
# Institute => NNP
# of => IN
# Chicago => NNP
# January => NNP
# 30-May => JJ
# 7 => CD
# 1993 => CD
# ISBN => NN
# 0-89207-099-4 => JJ
# Published => VBN
# by => IN
# the => DT
# Guggenheim => NNP
# Museum => NNP
# 1071 => CD
# Fifth => NNP
# Avenue => NNP
# New => NNP
# York => NNP
# New => NNP
# York => NNP
# 10128 => CD
# Prmted => NNP
# m => VBD
# the => DT
# United => NNP
# States => NNPS
# by => IN
# Thorner => NNP
# Press => NNP
# Front => NNP
# cover => NN
# Marc => NNP
# Chagall => NNP
# M/isk => NNP
# 1920 => CD
# Tempera => NNP
# and => CC
# gouache => NN
# on => IN
# canvas => NN
# 212.4 => CD
# ^ => JJ
# I03-5 => NNP
# cm => NN
# 83 => CD
# V => NNP
# « => NNP
# X => NNP
# 40 => CD
# V4 => NNP
# inches => NNS
# State => NNP
# Tret'iakov => NNP
# Gallery => NNP
# Moscow => NNP
# Back => NNP
# cover => NN
# Marc => NNP
# Chagall => NNP
# Loi'e => NNP
# on => IN
# the => DT
# Stage => NN
# 1920 => CD
# Tempera => NNP
# and => CC
# gouache => NN
# on => IN
# canvas => NN
# 284.2 => CD
# 249.6 => CD
# cm => NN
# in => IN
# 7s => CD
# x => JJ
# 98 => CD
# 'A => POS
# inches => NNS
# State => NNP
# Tret'iakov => NNP
# Gallery => NNP
# Moscow => NNP
# Frontispiece => NNP
# Emblem => NN
# of => IN
# the => DT
# Jewish => JJ
# Chamber => NNP
# Theater => NNP
# taken => VBN
# from => IN
# a => DT
# 1919 => CD
# poster => NN
# printed => VBN
# in => IN
# Petrograd => NNP
# Color => NN
# photography => NN
# Cat => NNP
# nos => NNS
# 1-7 => JJ
# from => IN
# State => NNP
# Tret'iakov => NNP
# Gallery => NNP
# Moscow => NNP
# nos => NNS
# I => PRP
# 2 => CD
# photo => NN
# H. => NNP
# Preisig => NNP
# no => DT
# 3 => CD
# courtesy => NN
# Fondation => NNP
# Pierre => NNP
# Gianadda => NNP
# nos => NNS
# 4-7 => JJ
# photographed => VBN
# by => IN
# Lee => NNP
# Ewing => NNP
# Cat => NNP
# nos => NNS
# 8 => CD
# 9 => CD
# 11 => CD
# 14 => CD
# from => IN
# Musee => NNP
# national => JJ
# d'art => NN
# moderne => NN
# Centre => NNP
# Georges => NNP
# Pompidou => NNP
# Paris => NNP
# photo => NN
# Philippe => NNP
# Migeat => NNP
# © => NNP
# Centre => NNP
# G. => NNP
# Pompidou => NNP
# Cat => NNP
# nos => NNS
# 10 => CD
# 12 => CD
# 13 => CD
# 15-20 => JJ
# from => IN
# the => DT
# collection => NN
# of => IN
# Ida => NNP
# Chagall => NNP
# Paris => NNP
# Cat => NNP
# nos => NNS
# 21—32 => CD
# from => IN
# Solomon => NNP
# R. => NNP
# Guggenheim => NNP
# Museum => NNP
# no => DT
# 24 => CD
# photographed => VBN
# by => IN
# Myles => NNP
# Aronowitz => NNP
# no => DT
# 29 => CD
# by => IN
# Lee => NNP
# Ewing => NNP
# nos => NNS
# 21 => CD
# 31 => CD
# 32 => CD
# by => IN
# Carmelo => NNP
# Guadagno => NNP
# nos => NNS
# 21-23 => JJ
# 2.5—28 => CD
# 30 => CD
# by => IN
# David => NNP
# Heald => NNP
# This => DT
# exhibition => NN
# has => VBZ
# been => VBN
# sponsored => VBN
# in => IN
# part => NN
# by => IN
# Lufthansa => JJ
# German => NNP
# Airlines => NNPS
# Lufthansa => NNP
# Additional => NNP
# support => NN
# has => VBZ
# been => VBN
# provided => VBN
# by => IN
# The => DT
# Helena => NNP
# Rubinstein => NNP
# Foundation => NNP
# Marc => NNP
# Chagall => NNP
# and => CC
# the => DT
# Jewish => JJ
# Theater => NNP
# Contents => NNP
# Preface => NNP
# Thomas => NNP
# Krens => NNP
# viii => NNP
# Fore => NNP
# & => CC
# gt => NN
# vord => CC
# h/rii => VB
# K. => NNP
# Korolev => NNP
# X => NNP
# Sponsor => NNP
# 's => POS
# Statement => NNP
# jiirgm => NN
# Weber => NNP
# xi => NNP
# Introduction => NNP
# Jeiuujer => NNP
# Bleising => NNP
# xii => NNP
# Chagall => NNP
# 's => POS
# Auditorium => NN
# An => DT
# Identity => NNP
# Crisis => NNP
# of => IN
# Tragic => NNP
# Dimensions => NNP
# ' => POS
# S/i.saii => NNP
# C => NNP
# ODiptoii => NNP
# I => PRP
# Chagall => VBP
# Postmodernism => NN
# and => CC
# Fictional => NNP
# Worlds => NNP
# in => IN
# Painting => NNP
# Benjamin => NNP
# Harshav => NNP
# 15 => CD
# Catalogue => NNP
# to => TO
# the => DT
# Exhibition => NNP
# 65 => CD
# Texts => NNP
# and => CC
# Documents => NNP
# Edited => NNP
# by => IN
# Benjamin => NNP
# Harshav => NNP
# Translated => VBN
# by => IN
# Benjamin => NNP
# and => CC
# Barbara => NNP
# Harshav => NNP
# 133 => CD
# Bibliography => NNP
# Benjamin => NNP
# Harshav => NNP
# 200 => CD
# Aftervs^ord => NNP
# Gregory => NNP
# Veitsman => NNP
# 205 => CD
# Alan- => NNP
# Chagall => NNP
# and => CC
# the => DT
# Jewish => JJ
# Theater => NNP
# appears => VBZ
# at => IN
# the => DT
# Gu^'genheim => NNP
# Museum => NNP
# SoHo => NNP
# while => IN
# The => DT
# Great => NNP
# Utopia => NNP
# The => DT
# R/issian => JJ
# and => CC
# Soviet => JJ
# Avant-Garde => NNP
# ipi => JJ
# -ip^2 => CD
# the => DT
# comprehensive => JJ
# exhibition => NN
# of => IN
# one => CD
# of => IN
# the => DT
# principal => JJ
# Modernist => NNP
# movements => NNS
# of => IN
# the => DT
# twentieth => JJ
# century => NN
# is => VBZ
# on => IN
# display => NN
# at => IN
# the => DT
# Solomon => NNP
# R. => NNP
# Guggenheim => NNP
# Museum => NNP
# The => DT
# Great => NNP
# Utopia => NNP
# presents => VBZ
# the => DT
# fruits => NNS
# ot => VBP
# the => DT
# avant-garde => NN
# 's => POS
# attempt => NN
# to => TO
# restructure => VB
# an => DT
# entire => JJ
# society => NN
# — => NNP
# economically => RB
# socially => RB
# and => CC
# culturally => RB
# — => VB
# in => IN
# the => DT
# face => NN
# of => IN
# a => DT
# tremendous => JJ
# political => JJ
# upheaval => NN
# the => DT
# Russian => JJ
# Revolution => NNP
# Artists => NNS
# became => VBD
# integral => JJ
# participants => NNS
# in => IN
# the => DT
# formation => NN
# ol => IN
# the => DT
# Soviet => JJ
# government => NN
# They => PRP
# also => RB
# strove => VBP
# to => TO
# create => VB
# new => JJ
# forms => NNS
# for => IN
# art => NN
# and => CC
# utilitarian => JJ
# objects => NNS
# that => WDT
# would => MD
# function => VB
# purposefully => RB
# to => TO
# bring => VB
# about => RB
# and => CC
# encourage => VB
# change => NN
# Stranded => VBN
# in => IN
# Russia => NNP
# during => IN
# a => DT
# visit => NN
# with => IN
# his => PRP$
# fiancee => NN
# before => IN
# World => NNP
# War => NNP
# I => PRP
# Marc => NNP
# Chagall => NNP
# participated => VBD
# in => IN
# revolutionary => JJ
# debates => NNS
# about => IN
# art => NN
# and => CC
# politics => NNS
# He => PRP
# was => VBD
# appointed => VBN
# the => DT
# Commissar => NNP
# of => IN
# Art => NNP
# for => IN
# the => DT
# region => NN
# of => IN
# Vitebsk => NNP
# and => CC
# founded => VBD
# an => DT
# art => NN
# academy => NN
# and => CC
# museum => NN
# in => IN
# his => PRP$
# official => JJ
# capacity => NN
# At => IN
# the => DT
# academy => NN
# Chagall => NNP
# 's => POS
# teachings => NNS
# were => VBD
# challenged => VBN
# by => IN
# Kazimir => NNP
# Malevich => NNP
# who => WP
# succeeded => VBD
# in => IN
# convincing => VBG
# the => DT
# school => NN
# 's => POS
# students => NNS
# of => IN
# the => DT
# primacy => NN
# of => IN
# his => PRP$
# Suprematism => NN
# The => DT
# Great => NNP
# Utopia => NNP
# serves => VBZ
# as => IN
# an => DT
# excellent => JJ
# background => NN
# for => IN
# Marc => NNP
# Chagall => NNP
# and => CC
# the => DT
# Jewish => JJ
# Theater => NN
# by => IN
# providing => VBG
# the => DT
# context => NN
# within => IN
# which => WDT
# Chagall => NNP
# in => IN
# 1920 => CD
# undertook => VBD
# his => PRP$
# commission => NN
# for => IN
# the => DT
# State => NNP
# Jewish => NNP
# Chamber => NNP
# Theater => NNP
# Marc => NNP
# Chagall => NNP
# and => CC
# the => DT
# Jewish => JJ
# Theater => NNP
# in => IN
# turn => NN
# can => MD
# be => VB
# viewed => VBN
# as => IN
# a => DT
# counterpoint => NN
# to => TO
# The => DT
# Great => NNP
# Utopia => NNP
# in => IN
# that => IN
# it => PRP
# presents => VBZ
# the => DT
# work => NN
# of => IN
# an => DT
# artist => NN
# whose => WP$
# methods => NNS
# of => IN
# representation => NN
# enigmatic => JJ
# symbolism => NN
# and => CC
# abstract => JJ
# individualist => NN
# ideology => NN
# left => VBD
# him => PRP
# at => IN
# odds => NNS
# with => IN
# many => JJ
# of => IN
# his => PRP$
# fellow => JJ
# artists => NNS
# and => CC
# hastened => VBD
# his => PRP$
# departure => NN
# from => IN
# Russia => NNP
# These => DT
# exhibitions => NNS
# have => VBP
# been => VBN
# both => DT
# blessed => VBN
# and => CC
# plagued => VBN
# by => IN
# the => DT
# myriad => NN
# changes => NNS
# in => IN
# the => DT
# former => JJ
# Soviet => NNP
# Union => NNP
# The => DT
# opening => NN
# of => IN
# previously => RB
# restricted => VBN
# archives => NNS
# and => CC
# the => DT
# willingness => NN
# to => TO
# cooperate => VB
# with => IN
# Western => JJ
# scholars => NNS
# and => CC
# institutions => NNS
# have => VBP
# led => VBN
# to => TO
# a => DT
# wealth => NN
# of => IN
# new => JJ
# studies => NNS
# on => IN
# the => DT
# pre- => NN
# and => CC
# postrevolutionary => JJ
# periods => NNS
# and => CC
# to => TO
# exhibitions => NNS
# of => IN
# works => NNS
# that => WDT
# may => MD
# not => RB
# have => VB
# been => VBN
# removed => VBN
# from => IN
# storage => NN
# in => IN
# the => DT
# Soviet => NNP
# Union => NNP
# much => RB
# less => JJR
# been => VBN
# lent => JJ
# to => TO
# museums => NNS
# in => IN
# other => JJ
# countries => NNS
# An => DT
# exhibition => NN
# of => IN
# Chagall => NNP
# 's => POS
# murals => NNS
# for => IN
# the => DT
# Jewish => JJ
# Theater => NNP
# was => VBD
# unthinkable => JJ
# a => DT
# few => JJ
# short => JJ
# years => NNS
# ago => RB
# The => DT
# rapidity => NN
# of => IN
# change => NN
# in => IN
# the => DT
# Russian => JJ
# political => JJ
# situation => NN
# in => IN
# recent => JJ
# years => NNS
# created => VBD
# unique => JJ
# logistical => JJ
# and => CC
# technical => JJ
# difficulties => NNS
# that => WDT
# had => VBD
# to => TO
# be => VB
# overcome => VBN
# Without => IN
# the => DT
# dedicated => JJ
# commitment => NN
# of => IN
# our => PRP$
# Russian => JJ
# partners => NNS
# as => RB
# well => RB
# as => IN
# of => IN
# many => JJ
# individuals => NNS
# and => CC
# institutions => NNS
# in => IN
# Europe => NNP
# and => CC
# the => DT
# United => NNP
# States => NNPS
# this => DT
# show => NN
# would => MD
# not => RB
# be => VB
# possible => JJ
# We => PRP
# are => VBP
# most => RBS
# indebted => JJ
# to => TO
# lurii => VB
# Korolev => NNP
# Director => NNP
# of => IN
# the => DT
# State => NNP
# Tret'iakov => NNP
# Gallery => NNP
# Moscow => NNP
# and => CC
# his => PRP$
# staff => NN
# Among => IN
# them => PRP
# Lidiia => NNP
# Romashkova => NNP
# Chief => NNP
# Registrar => NNP
# and => CC
# Deputy => NNP
# Director => NNP
# played => VBD
# a => DT
# key => JJ
# role => NN
# The => DT
# Tret'iakov => NNP
# Gallery => NNP
# has => VBZ
# cared => VBN
# for => IN
# Chagall => NNP
# 's => POS
# seven => CD
# murals => NNS
# for => IN
# the => DT
# Jewish => JJ
# Theater => NNP
# since => IN
# 1950 => CD
# when => WRB
# they => PRP
# were => VBD
# admitted => VBN
# to => TO
# the => DT
# museum => NN
# These => DT
# paintings => NNS
# would => MD
# not => RB
# be => VB
# on => IN
# display => NN
# today => NN
# without => IN
# the => DT
# meticulous => JJ
# restoration => NN
# work => NN
# led => VBN
# by => IN
# Aleksei => NNP
# Kovalev => NNP
# Director => NNP
# of => IN
# the => DT
# Restoration => NNP
# Department => NNP
# and => CC
# his => PRP$
# team => NN
# including => VBG
# Leonid => NNP
# Astafev => NNP
# and => CC
# Galina => NNP
# lushkevich => NN
# The => DT
# participation => NN
# of => IN
# Evgenii => NNP
# Sidorov => NNP
# the => DT
# Minister => NNP
# of => IN
# Thomas => NNP
# Krem => NNP
# Culture => NNP
# of => IN
# the => DT
# Russian => JJ
# Federation => NNP
# was => VBD
# vital => JJ
# to => TO
# the => DT
# success => NN
# of => IN
# the => DT
# project => NN
# A => DT
# number => NN
# of => IN
# collectors => NNS
# and => CC
# institutions => NNS
# were => VBD
# extremely => RB
# generous => JJ
# in => IN
# agreeing => VBG
# to => TO
# lend => VB
# us => PRP
# important => JJ
# works => NNS
# with => IN
# the => DT
# short => JJ
# notice => NN
# that => WDT
# resulted => VBD
# from => IN
# our => PRP$
# scheduling => NN
# requirements => NNS
# Madame => NNP
# Ida => NNP
# Chagall => NNP
# daughter => NN
# of => IN
# the => DT
# artist => NN
# selflessly => RB
# lent => JJ
# nine => CD
# sketches => NNS
# from => IN
# her => PRP$
# collection => NN
# Our => PRP$
# exhibition => NN
# would => MD
# be => VB
# incomplete => JJ
# without => IN
# these => DT
# essential => JJ
# works => NNS
# related => VBN
# to => TO
# the => DT
# commission => NN
# for => IN
# the => DT
# Jewish => JJ
# Theater => NNP
# We => PRP
# must => MD
# also => RB
# thank => VB
# Meret => NNP
# Meyer => NNP
# Ida => NNP
# Chagall => NNP
# 's => POS
# daughter => NN
# for => IN
# facilitating => VBG
# the => DT
# transmission => NN
# of => IN
# photographs => NN
# The => DT
# contribution => NN
# of => IN
# Franz => NNP
# Meyer => NNP
# the => DT
# author => NN
# of => IN
# the => DT
# artist => NN
# 's => POS
# first => JJ
# catalogue => NN
# raisonne => NN
# was => VBD
# indispensable => JJ
# to => TO
# the => DT
# exhibition => NN
# The => DT
# Musee => NNP
# national => JJ
# dart => NN
# moderne => NN
# Centre => NNP
# Georges => NNP
# Pompidou => NNP
# Paris => NNP
# lent => VBD
# additional => JJ
# theater => NN
# drawings => NNS
# including => VBG
# the => DT
# preparatory => NN
# sketch => NN
# for => IN
# the => DT
# Guggenheim => NNP
# 's => POS
# Green => NNP
# Violinist => NNP
# We => PRP
# offer => VBP
# our => PRP$
# special => JJ
# thanks => NNS
# to => TO
# Dominique => NNP
# Bozo => NNP
# President => NNP
# of => IN
# the => DT
# Centre => NNP
# Georges => NNP
# Pompidou => NNP
# and => CC
# Germain => NNP
# Viatte => NNP
# the => DT
# Musee => NNP
# national => JJ
# d'art => NN
# moderne => NN
# 's => POS
# Director => NNP
# Additional => JJ
# assistance => NN
# was => VBD
# offered => VBN
# by => IN
# Curator => NNP
# Didier => NNP
# Schulmann => NNP
# who => WP
# is => VBZ
# compiling => VBG
# the => DT
# Chagall => NNP
# catalogue => NN
# raisonne => NN
# for => IN
# the => DT
# museum => NN
# and => CC
# Collection => NNP
# Registrar => NNP
# Viviane => NNP
# Faret => NNP
# who => WP
# helped => VBD
# us => PRP
# navigate => VB
# the => DT
# loan => NN
# procedures => NNS
# for => IN
# the => DT
# popular => JJ
# works => NNS
# The => DT
# State => NNP
# Bakhrushin => NNP
# Museum => NNP
# Moscow => NNP
# under => IN
# the => DT
# direction => NN
# of => IN
# Valerii => NNP
# Gubin => NNP
# lent => VBD
# four => CD
# sketches => NNS
# by => IN
# Chagall => NNP
# 's => POS
# contemporaries => NNS
# who => WP
# designed => VBD
# productions => NNS
# for => IN
# the => DT
# Jewish => JJ
# Theater => NNP
# We => PRP
# have => VBP
# been => VBN
# the => DT
# beneficiaries => NNS
# of => IN
# this => DT
# museum => NN
# 's => POS
# profound => JJ
# contribution => NN
# to => TO
# the => DT
# preservation => NN
# and => CC
# restoration => NN
# of => IN
# theatrical => JJ
# objects => NNS
# from => IN
# the => DT
# early => JJ
# Soviet => JJ
# period => NN
# including => VBG
# an => DT
# extensive => JJ
# archive => NN
# of => IN
# documentary => JJ
# material => NN
# The => DT
# Central => NNP
# State => NNP
# Archive => NNP
# for => IN
# Literature => NNP
# and => CC
# Art => NNP
# Moscow => NNP
# directed => VBN
# by => IN
# Natal'ia => NNP
# Volkova => NNP
# generously => RB
# lent => JJ
# rare => JJ
# 1920s => CD
# posters => NNS
# for => IN
# the => DT
# theater => NN
# among => IN
# them => PRP
# an => DT
# important => JJ
# broadsheet => NN
# believed => VBD
# to => TO
# be => VB
# the => DT
# first => JJ
# poster => NN
# mentioning => VBG
# Chagall => NNP
# In => IN
# 1991 => CD
# the => DT
# murals => NNS
# were => VBD
# exhibited => VBN
# en => IN
# suite => NN
# for => IN
# the => DT
# first => JJ
# time => NN
# in => IN
# the => DT
# West => NNP
# at => IN
# the => DT
# Fondation => NNP
# Pierre => NNP
# Gianadda => NNP
# in => IN
# Martigny => NNP
# Switzerland => NNP
# which => WDT
# sponsored => VBD
# their => PRP$
# restoration => NN
# We => PRP
# must => MD
# thank => VB
# the => DT
# foundation => NN
# 's => POS
# President => NNP
# Leonard => NNP
# Gianadda => NNP
# as => RB
# well => RB
# as => IN
# Christoph => NNP
# Vitali => NNP
# Director => NNP
# of => IN
# the => DT
# Schirn => NNP
# Kunsthalle => NNP
# Frankfurt => NNP
# Their => PRP$
# institutions => NNS
# ' => POS
# exhibitions => NNS
# and => CC
# catalogues => NNS
# provided => VBD
# both => DT
# inspiration => NN
# and => CC
# substantial => JJ
# new => JJ
# material => NN
# on => IN
# Chagall => NNP
# 's => POS
# murals => NNS
# Mr. => NNP
# Vitali => NNP
# lent => VBD
# the => DT
# Guggenheim => NNP
# numerous => JJ
# historical => JJ
# photographs => NN
# and => CC
# provided => VBD
# important => JJ
# technical => JJ
# advice => NN
# Marc => NNP
# Chagall => NNP
# and => CC
# the => DT
# Jewish => JJ
# Theater => NN
# might => MD
# never => RB
# have => VB
# been => VBN
# realized => VBN
# without => IN
# the => DT
# assistance => NN
# of => IN
# Lufthansa => JJ
# German => NNP
# Airlines => NNPS
# and => CC
# its => PRP$
# Chairman => NNP
# Jiargen => NNP
# Weber => NNP
# Nicolas => NNP
# V. => NNP
# Iljine => NNP
# Manager => NNP
# of => IN
# Public => NNP
# Affairs => NNPS
# arranged => VBD
# and => CC
# coordinated => VBD
# extensive => JJ
# transportation => NN
# services => NNS
# and => CC
# his => PRP$
# enthusiastic => JJ
# interest => NN
# throughout => IN
# the => DT
# show => NN
# 's => POS
# development => NN
# was => VBD
# a => DT
# continuously => RB
# important => JJ
# source => NN
# of => IN
# encouragement => NN
# Through => IN
# his => PRP$
# capable => JJ
# offices => NNS
# we => PRP
# were => VBD
# able => JJ
# to => TO
# obtain => VB
# much => JJ
# of => IN
# the => DT
# documentary => JJ
# material => NN
# that => WDT
# is => VBZ
# the => DT
# basis => NN
# of => IN
# the => DT
# informational => JJ
# component => NN
# of => IN
# the => DT
# exhibition => NN
# Additional => JJ
# support => NN
# was => VBD
# provided => VBN
# by => IN
# the => DT
# Helena => NNP
# Rubinstein => NNP
# Foundation => NNP
# for => IN
# which => WDT
# we => PRP
# are => VBP
# grateful => JJ
# Preface => NN
# and => CC
# Acknov\^ledgments => NNP
# Valentin => NNP
# Rivkind => NNP
# Deputy => NNP
# Director => NNP
# ot => VBD
# the => DT
# Vuchetich => NNP
# All- => NNP
# Union => NNP
# Artistic => NNP
# Production => NNP
# Association => NNP
# VUART => NNP
# Moscow => NNP
# was => VBD
# instrumental => JJ
# in => IN
# securing => VBG
# all => DT
# loans => NNS
# of => IN
# art => NN
# from => IN
# Russia => NNP
# a => DT
# very => RB
# complicated => JJ
# task => NN
# due => JJ
# to => TO
# the => DT
# volatile => JJ
# political => JJ
# and => CC
# economic => JJ
# situation => NN
# The => DT
# assistance => NN
# and => CC
# enthusiasm => NN
# of => IN
# Zel'fira => NNP
# Tregulova => NNP
# art => NN
# expert => NN
# and => CC
# Deputy => NNP
# Chief => NNP
# of => IN
# the => DT
# exhibition => NN
# department => NN
# at => IN
# VUART => NNP
# was => VBD
# fundamental => JJ
# to => TO
# the => DT
# realization => NN
# of => IN
# this => DT
# project => NN
# She => PRP
# was => VBD
# a => DT
# model => NN
# of => IN
# efficiency => NN
# and => CC
# grace => NN
# under => IN
# pressure => NN
# Marc => NNP
# Chagall => NNP
# 6jnd => CD
# the => DT
# Jewish => JJ
# Theater => NNP
# has => VBZ
# profited => VBN
# from => IN
# the => DT
# initiatives => NNS
# taken => VBN
# by => IN
# Russian => JJ
# scholars => NNS
# Aleksandra => NNP
# Shatskikh => NNP
# 's => POS
# extensive => JJ
# research => NN
# into => IN
# the => DT
# life => NN
# and => CC
# work => NN
# of => IN
# Chagall => NNP
# is => VBZ
# amply => RB
# demonstrated => VBN
# by => IN
# her => PRP$
# contributions => NNS
# to => TO
# the => DT
# Schirn => NNP
# Kunsthalle => NNP
# Frankfurt => NNP
# 's => POS
# catalogue => NN
# Our => PRP$
# knowledge => NN
# of => IN
# the => DT
# commission => NN
# for => IN
# the => DT
# Jewish => JJ
# Theater => NNP
# has => VBZ
# been => VBN
# greatly => RB
# enriched => VBN
# by => IN
# her => PRP$
# work => NN
# We => PRP
# are => VBP
# also => RB
# grateful => JJ
# to => TO
# Zara => NNP
# Abdulaeva => NNP
# for => IN
# her => PRP$
# research => NN
# on => IN
# the => DT
# Jewish => JJ
# Theater => NNP
# which => WDT
# we => PRP
# relied => VBD
# upon => IN
# for => IN
# the => DT
# production => NN
# history => NN
# presented => VBN
# in => IN
# the => DT
# exhibition => NN
# Christiane => NNP
# Bauermeister => NNP
# of => IN
# Ost-West-Kultur => NNP
# facilitated => VBD
# communication => NN
# between => IN
# various => JJ
# parties => NNS
# in => IN
# Russia => NNP
# and => CC
# New => NNP
# York => NNP
# In => IN
# Moscow => NNP
# we => PRP
# benefited => VBD
# from => IN
# the => DT
# participation => NN
# of => IN
# Rada => NNP
# Abdulaeva => NNP
# Liubov => NNP
# ' => POS
# Chistiakova => NNP
# Irina => NNP
# Duksina => NNP
# Matvei => NNP
# Geizer => NNP
# Natal'ia => NNP
# lakimova => NN
# Boris => NNP
# Karad'ev => NNP
# Tat'iana => NNP
# Klim => NNP
# Elena => NNP
# Korenevskaia => NNP
# Alia => NNP
# Lukanova => NNP
# Rada => NNP
# Mamedova => NNP
# Vjatscheslaw => NNP
# Nechaev => NNP
# Anait => NNP
# Oganessian => NNP
# Igor => NNP
# Pal'min => NNP
# Il'ia => NNP
# Plotkin => NNP
# Ekaterina => NNP
# Seleznova => NNP
# Mikhail => NNP
# Shvydkoi => NNP
# and => CC
# Boris => NNP
# Zingerman => NNP
# We => PRP
# also => RB
# received => VBD
# help => NN
# from => IN
# Aleksei => NNP
# Bessobrasov => NNP
# St. => NNP
# Petersburg => NNP
# Natan => NNP
# Fedorowskii => NNP
# Berlin => NNP
# David => NNP
# Hasan => NNP
# Helsinki => NNP
# Sam => NNP
# Norich => NNP
# New => NNP
# York => NNP
# and => CC
# Elena => NNP
# Rakitin => NNP
# Frankfurt => NNP
# The => DT
# dedication => NN
# of => IN
# and => CC
# sheer => VB
# hard => JJ
# work => NN
# by => IN
# Guggenheim => NNP
# staff => NN
# members => NNS
# made => VBD
# this => DT
# exhibition => NN
# possible => JJ
# In => IN
# spring => NN
# 1992 => CD
# a => DT
# team => NN
# was => VBD
# created => VBN
# to => TO
# bring => VB
# the => DT
# exhibition => NN
# to => TO
# fruition => NN
# which => WDT
# included => VBD
# Michael => NNP
# Govan => NNP
# Deputy => NNP
# Director => NNP
# and => CC
# Maryann => NNP
# Jordan => NNP
# Director => NNP
# of => IN
# External => NNP
# Affairs => NNPS
# who => WP
# quickly => RB
# began => VBD
# to => TO
# mobilize => VB
# the => DT
# museum => NN
# 's => POS
# resources => NNS
# Jennifer => NNP
# Blessing => NNP
# Assistant => NNP
# Curator => NNP
# for => IN
# Research => NNP
# spearheaded => VBD
# the => DT
# curatorial => JJ
# organization => NN
# of => IN
# the => DT
# exhibition => NN
# She => PRP
# was => VBD
# ably => RB
# assisted => VBN
# by => IN
# Emily => NNP
# Locker => NNP
# Project => NNP
# Research => NNP
# Assistant => NNP
# whose => WP$
# Russian-language => JJ
# skills => NNS
# and => CC
# meticulous => JJ
# attention => NN
# to => TO
# detail => VB
# were => VBD
# a => DT
# tremendous => JJ
# asset => NN
# At => IN
# crucial => JJ
# moments => NNS
# Carmen => NNP
# Gimenez => NNP
# Curator => NNP
# of => IN
# Twentieth-Century => NNP
# Art => NNP
# participated => VBD
# in => IN
# loan => NN
# negotiations => NNS
# and => CC
# Jane => NNP
# Sharp => NNP
# Project => NNP
# Associate => NNP
# Curator => NNP
# for => IN
# The => DT
# Great => NNP
# Utopia => NNP
# lent => VBD
# her => PRP$
# expertise => NN
# to => TO
# the => DT
# Chagall => NNP
# show => NN
# when => WRB
# needed => VBN
# Sharon => NNP
# Corwin => NNP
# Curatorial => NNP
# Intern => NNP
# solved => VBD
# numerous => JJ
# problems => NNS
# of => IN
# logistics => NNS
# during => IN
# her => PRP$
# short => JJ
# summer => NN
# tenure => NN
# The => DT
# Technical => NNP
# Services => NNPS
# staff => NN
# headed => VBN
# by => IN
# Pamela => NNP
# Myers => NNP
# Administrator => NNP
# for => IN
# Exhibitions => NNP
# and => CC
# Programming => NNP
# took => VBD
# on => IN
# the => DT
# task => NN
# of => IN
# designing => VBG
# planning => NN
# and => CC
# mounting => VBG
# this => DT
# exhibition => NN
# in => IN
# six => CD
# short => JJ
# months => NNS
# Peter => NNP
# Costa => NNP
# Senior => NNP
# Museum => NNP
# Technician => NNP
# was => VBD
# key => JJ
# to => TO
# its => PRP$
# installation => NN
# Andrew => NNP
# Law => NNP
# Simons => NNP
# associate => JJ
# designer => NN
# designed => VBN
# the => DT
# didactic => JJ
# component => NN
# of => IN
# the => DT
# exhibition => NN
# he => PRP
# also => RB
# designed => VBD
# the => DT
# the => DT
# catalogue => NN
# based => VBN
# on => IN
# a => DT
# format => NN
# by => IN
# Massimo => NNP
# Vignelli => NNP
# The => DT
# commitment => NN
# of => IN
# the => DT
# Publications => NNP
# Department => NNP
# led => VBN
# by => IN
# Anthony => NNP
# Calnek => NNP
# Managing => NNP
# Editor => NNP
# was => VBD
# no => DT
# less => RBR
# essential => JJ
# to => TO
# the => DT
# success => NN
# of => IN
# this => DT
# project => NN
# Despite => IN
# numerous => JJ
# other => JJ
# obligations => NNS
# Mr. => NNP
# Calnek => NNP
# Laura => NNP
# Morris => NNP
# Assistant => NNP
# Editor => NNP
# and => CC
# Jennifer => NNP
# Knox => NNP
# Editorial => NNP
# Assistant => NNP
# responded => VBD
# to => TO
# their => PRP$
# labors => NNS
# with => IN
# fortitude => NN
# and => CC
# good => JJ
# spirits => NNS
# Paul => NNP
# Schwartzbaum => NNP
# Assistant => NNP
# Director => NNP
# for => IN
# Technical => NNP
# Services => NNP
# and => CC
# Chief => NNP
# Conservator => NNP
# was => VBD
# involved => VBN
# in => IN
# the => DT
# exhibition => NN
# from => IN
# its => PRP$
# inception => NN
# His => PRP$
# expertise => NN
# in => IN
# overseeing => VBG
# the => DT
# care => NN
# of => IN
# the => DT
# murals => NNS
# and => CC
# in => IN
# negotiating => VBG
# technical => JJ
# issues => NNS
# has => VBZ
# been => VBN
# indispensable => JJ
# Jan => NNP
# Adlmann => NNP
# Director => NNP
# of => IN
# Special => NNP
# Programs => NNP
# organized => VBD
# the => DT
# symposium => NN
# Two => CD
# Lectures/New => NNP
# Insights => NNS
# Marc => NNP
# Chagall => NNP
# 's => POS
# Jewish => JJ
# Theater => NNP
# Project => NNP
# in => IN
# conjunction => NN
# with => IN
# the => DT
# 92nd => CD
# Street => NNP
# Y => NNP
# Among => IN
# the => DT
# many => JJ
# other => JJ
# staff => NN
# members => NNS
# who => WP
# made => VBD
# contributions => NNS
# were => VBD
# Lynne => NNP
# Addison => NNP
# Associate => NNP
# Registrar => NNP
# who => WP
# handily => RB
# took => VBD
# over => RP
# the => DT
# responsibilities => NNS
# of => IN
# the => DT
# exhibition => NN
# midstream => NN
# after => IN
# joining => VBG
# the => DT
# museum => NN
# and => CC
# Heidi => NNP
# Rosenau => NNP
# the => DT
# Public => NNP
# Affairs => NNPS
# Coordinator => NNP
# responsible => JJ
# for => IN
# the => DT
# Chagall => NNP
# exhibition => NN
# who => WP
# discharged => VBD
# her => PRP$
# duties => NNS
# with => IN
# intelligence => NN
# and => CC
# grace => NN
# Finally => RB
# we => PRP
# owe => VBP
# our => PRP$
# thanks => NNS
# to => TO
# this => DT
# catalogue => NN
# 's => POS
# contributors => NNS
# who => WP
# committed => VBD
# themselves => PRP
# to => TO
# the => DT
# project => NN
# despite => IN
# our => PRP$
# short => JJ
# deadlines => NNS
# Dr. => NNP
# Susan => NNP
# Compton => NNP
# the => DT
# eminent => NN
# Chagall => NNP
# specialist => NN
# and => CC
# Dr. => NNP
# Benjamin => NNP
# Harshav => NNP
# J. => NNP
# and => CC
# H. => NNP
# Blaustein => NNP
# Professor => NNP
# of => IN
# Hebrew => NNP
# and => CC
# Comparative => NNP
# Literature => NNP
# at => IN
# Yale => NNP
# University => NNP
# have => VBP
# made => VBN
# immeasurable => JJ
# contributions => NNS
# to => TO
# Chagall => VB
# scholarship => NN
# Barbara => NNP
# Harshav => NNP
# translated => VBD
# with => IN
# Dr. => NNP
# Harshav => NNP
# the => DT
# extensive => JJ
# selection => NN
# of => IN
# primary => JJ
# texts => NNS
# included => VBD
# herein => NN
# Gregory => NNP
# Veitsman => NNP
# former => JJ
# Assistant => NNP
# Director => NNP
# for => IN
# Technical => NNP
# Services => NNP
# at => IN
# the => DT
# State => NNP
# Tret'iakov => NNP
# Gallery => NNP
# shares => NNS
# his => PRP$
# recollections => NNS
# of => IN
# Chagall => NNP
# in => IN
# the => DT
# afterword => NN
# — => JJ
# Thomas => NNP
# Krens => NNP
# Director => NNP
# The => DT
# Solomon => NNP
# R. => NNP
# Guggenheim => NNP
# Foundation => NNP
# Preface => NNP
# and => CC
# Acknowhdgimnti => NNP
# 1 => CD
# ix => NN
# ForevN^ord => NNP
# The => DT
# monumental => JJ
# murals => NNS
# Marc => NNP
# Chagall => NNP
# created => VBD
# in => IN
# 1920 => CD
# for => IN
# the => DT
# State => NNP
# Jewish => NNP
# Chamber => NNP
# Theater => NNP
# in => IN
# Moscow => NNP
# GOSEKT => NNP
# were => VBD
# the => DT
# last => JJ
# works => VBZ
# the => DT
# master => NN
# made => VBN
# in => IN
# his => PRP$
# native => JJ
# land => NN
# His => PRP$
# artistic => JJ
# achievement => NN
# was => VBD
# immediately => RB
# recognized => VBN
# by => IN
# critics => NNS
# and => CC
# art => NN
# scholars => NNS
# Therefore => RB
# after => IN
# the => DT
# theater => NN
# was => VBD
# closed => VBN
# in => IN
# 1949 => CD
# it => PRP
# was => VBD
# no => DT
# accident => NN
# that => IN
# the => DT
# State => NNP
# Tret'iakov => NNP
# Gallery => NNP
# the => DT
# country => NN
# 's => POS
# leading => VBG
# museum => NN
# acquired => VBD
# the => DT
# panels => NNS
# for => IN
# their => PRP$
# permanent => JJ
# collection => NN
# There => EX
# cared => VBD
# for => IN
# by => IN
# restorers => NNS
# and => CC
# curators => NNS
# the => DT
# murals => NNS
# were => VBD
# kept => VBN
# on => IN
# drums => NNS
# because => IN
# of => IN
# their => PRP$
# large => JJ
# size => NN
# They => PRP
# were => VBD
# unrolled => VBN
# to => TO
# check => VB
# for => IN
# damage => NN
# on => IN
# a => DT
# regular => JJ
# but => CC
# infrequent => JJ
# basis => NN
# because => IN
# of => IN
# the => DT
# fragility => NN
# of => IN
# their => PRP$
# backing => NN
# and => CC
# paint => NN
# layers => NNS
# When => WRB
# the => DT
# artist => NN
# visited => VBD
# the => DT
# Tret'iakov => NNP
# Gallery => NNP
# in => IN
# 1973 => CD
# he => PRP
# was => VBD
# delighted => VBN
# by => IN
# the => DT
# careful => JJ
# treatment => NN
# the => DT
# murals => NNS
# had => VBD
# received => VBN
# and => CC
# he => PRP
# signed => VBD
# and => CC
# dated => VBD
# them => PRP
# at => IN
# that => DT
# time => NN
# Until => IN
# perhaps => RB
# the => DT
# late => JJ
# 1960s => NNS
# he => PRP
# had => VBD
# not => RB
# even => RB
# known => VBN
# that => IN
# the => DT
# works => NNS
# had => VBD
# survived => VBN
# During => IN
# the => DT
# many => JJ
# years => NNS
# the => DT
# murals => NNS
# were => VBD
# in => IN
# storage => NN
# our => PRP$
# experts => NNS
# could => MD
# only => RB
# undertake => VB
# measures => NNS
# to => TO
# protect => VB
# the => DT
# panels => NNS
# There => EX
# was => VBD
# no => DT
# possibility => NN
# of => IN
# restoration => NN
# and => CC
# there => RB
# was => VBD
# nowhere => RB
# large => JJ
# enough => RB
# to => TO
# display => VB
# them => PRP
# in => IN
# the => DT
# museum => NN
# 's => POS
# old => JJ
# exhibition => NN
# galleries => NNS
# When => WRB
# the => DT
# museum => NN
# underwent => NN
# major => JJ
# reconstruction => NN
# and => CC
# plans => NNS
# were => VBD
# made => VBN
# to => TO
# expand => VB
# exhibition => NN
# space => NN
# the => DT
# question => NN
# of => IN
# displaying => VBG
# kinds => NNS
# of => IN
# paintings => NNS
# never => RB
# shown => VBN
# before => IN
# arose => NN
# We => PRP
# wrestled => VBD
# with => IN
# the => DT
# difficulties => NNS
# of => IN
# restoring => VBG
# and => CC
# exhibiting => VBG
# such => JJ
# works => NNS
# as => IN
# Chagall => NNP
# 's => POS
# theater => NN
# panels => NNS
# and => CC
# Vrubel => NNP
# 's => POS
# panel => NN
# Priucess => NNP
# Gnzci => NNP
# The => DT
# singular => JJ
# history => NN
# of => IN
# Chagall => NNP
# 's => POS
# murals => NNS
# — => VBP
# including => VBG
# their => PRP$
# creation => NN
# in => IN
# the => DT
# extreme => JJ
# conditions => NNS
# of => IN
# postrevolutionary => JJ
# Russia => NNP
# the => DT
# nature => NN
# of => IN
# their => PRP$
# materials => NNS
# tempera => NN
# and => CC
# gouache => NN
# on => IN
# thin => JJ
# linen => NN
# their => PRP$
# subsequent => JJ
# fate => NN
# determined => VBN
# by => IN
# dramatic => JJ
# twists => NNS
# and => CC
# turns => NNS
# such => JJ
# as => IN
# the => DT
# theater => NN
# 's => POS
# move => NN
# from => IN
# Bol'shoi => NNP
# Chernyshevskii => NNP
# Lane => NNP
# to => TO
# Malaia => NNP
# Bronnaia => NNP
# Street => NNP
# and => CC
# the => DT
# far- => JJ
# from-ideal => JJ
# storage => NN
# conditions => NNS
# from => IN
# 1938 => CD
# through => IN
# the => DT
# war => NN
# — => NN
# was => VBD
# reflected => VBN
# in => IN
# their => PRP$
# appearance => NN
# The => DT
# restorers => NNS
# had => VBD
# to => TO
# deal => VB
# with => IN
# wrinkling => NN
# of => IN
# the => DT
# backing => NN
# weak => JJ
# threads => NNS
# holding => VBG
# the => DT
# damaged => VBN
# parts => NNS
# of => IN
# the => DT
# linen => NN
# together => RB
# scratches => NNS
# and => CC
# large => JJ
# areas => NNS
# where => WRB
# the => DT
# paint => NN
# was => VBD
# missing => VBG
# or => CC
# flaking => NN
# They => PRP
# also => RB
# had => VBD
# to => TO
# reinforce => VB
# Chagall => NNP
# 's => POS
# canvas => NN
# This => DT
# extremely => RB
# complicated => JJ
# work => NN
# was => VBD
# carried => VBN
# out => RP
# by => IN
# the => DT
# Tret'iakov => NNP
# Gallery => NNP
# 's => POS
# restorers => NNS
# Aleksei => NNP
# Kovalev => NNP
# the => DT
# director => NN
# of => IN
# the => DT
# department => NN
# who => WP
# developed => VBD
# a => DT
# unique => JJ
# method => NN
# for => IN
# treating => VBG
# the => DT
# murals => NNS
# Leonid => NNP
# Astaf => NNP
# ev => NN
# and => CC
# Galina => NNP
# lushkevich => NN
# The => DT
# obstacle => NN
# of => IN
# the => DT
# cost => NN
# of => IN
# such => PDT
# a => DT
# complicated => JJ
# restoration => NN
# project => NN
# was => VBD
# overcome => VBN
# by => IN
# means => NNS
# of => IN
# international => JJ
# collaboration => NN
# It => PRP
# was => VBD
# decided => VBN
# that => IN
# the => DT
# murals => NNS
# would => MD
# be => VB
# exhibited => VBN
# in => IN
# various => JJ
# countries => NNS
# throughout => IN
# the => DT
# world => NN
# until => IN
# the => DT
# reconstruction => NN
# of => IN
# the => DT
# museum => NN
# was => VBD
# complete => JJ
# The => DT
# high => JJ
# quality => NN
# of => IN
# the => DT
# restoration => NN
# which => WDT
# won => VBD
# a => DT
# prize => NN
# in => IN
# Ferrara => NNP
# in => IN
# 1991 => CD
# enabled => VBD
# an => DT
# extensive => JJ
# exhibition => NN
# tour => NN
# The => DT
# paintings => NNS
# were => VBD
# first => JJ
# shown => VBN
# in => IN
# Switzerland => NNP
# at => IN
# the => DT
# Fondation => NNP
# Pierre => NNP
# Gianadda => NNP
# Martigny => NNP
# which => WDT
# financed => VBD
# the => DT
# restoration => NN
# The => DT
# exhibition => NN
# then => RB
# traveled => VBD
# to => TO
# the => DT
# Schirn => NNP
# Kunsthalle => NNP
# Frankfurt => NNP
# the => DT
# State => NNP
# Tret'iakov => NNP
# Gallery => NNP
# Moscow => NNP
# and => CC
# the => DT
# State => NNP
# Russian => NNP
# Museum => NNP
# in => IN
# St. => NNP
# Petersburg => NNP
# In => IN
# all => DT
# of => IN
# these => DT
# exhibitions => NNS
# which => WDT
# proved => VBD
# to => TO
# be => VB
# very => RB
# successful => JJ
# the => DT
# murals => NNS
# were => VBD
# shown => VBN
# in => IN
# the => DT
# context => NN
# of => IN
# Chagall => NNP
# 's => POS
# Russian => JJ
# period => NN
# Now => RB
# the => DT
# murals => NNS
# have => VBP
# reached => VBN
# North => NNP
# America => NNP
# and => CC
# New => NNP
# York => NNP
# the => DT
# Foreword => NNP
# most => RBS
# distant => JJ
# place => NN
# on => IN
# the => DT
# tour => NN
# I => PRP
# wish => VBP
# to => TO
# express => VB
# my => PRP$
# profound => JJ
# thanks => NNS
# to => TO
# my => PRP$
# colleague => NN
# Thomas => NNP
# Krens => NNP
# the => DT
# Director => NNP
# of => IN
# the => DT
# Solomon => NNP
# R. => NNP
# Guggenheim => NNP
# Foundation => NNP
# and => CC
# Deputy => NNP
# Director => NNP
# Michael => NNP
# Govan => NNP
# for => IN
# bringing => VBG
# the => DT
# exhibition => NN
# Marc => NNP
# Chagall => NNP
# and => CC
# the => DT
# Jewish => JJ
# Theater => NNP
# to => TO
# the => DT
# United => NNP
# States => NNPS
# I => PRP
# would => MD
# especially => RB
# like => VB
# to => TO
# thank => VB
# Nicolas => NNP
# V. => NNP
# Iljine => NNP
# Manager => NNP
# of => IN
# Public => NNP
# Affairs => NNPS
# of => IN
# Lufthansa => JJ
# German => NNP
# Airlines => NNPS
# for => IN
# his => PRP$
# enormous => JJ
# interest => NN
# in => IN
# the => DT
# exhibition => NN
# and => CC
# the => DT
# energy => NN
# he => PRP
# devoted => VBD
# toward => IN
# it => PRP
# I => PRP
# hope => VBP
# all => DT
# visitors => NNS
# to => TO
# the => DT
# exhibition => NN
# will => MD
# enjoy => VB
# their => PRP$
# encounter => NN
# with => IN
# Chagall => NNP
# 's => POS
# legendary => JJ
# panels => NNS
# the => DT
# only => RB
# great => JJ
# works => NNS
# of => IN
# a => DT
# monumental => JJ
# scale => NN
# the => DT
# artist => NN
# created => VBD
# in => IN
# Russia => NNP
# which => WDT
# the => DT
# critics => NNS
# of => IN
# the => DT
# 1920s => CD
# agreed => VBD
# were => VBD
# his => PRP$
# best => JJS
# works => NNS
# — => JJ
# lurii => NN
# K. => NNP
# Korolev => NNP
# General => NNP
# Director => NNP
# State => NNP
# Tret'iakov => NNP
# Gallery => NNP
# Moscow => NNP
# Sponsor'is => NNP
# Statement => NNP
# The => DT
# legendary => JJ
# monumental => JJ
# murals => NNS
# Chagall => NNP
# created => VBD
# in => IN
# 1920 => CD
# for => IN
# the => DT
# auditorium => NN
# of => IN
# Moscow => NNP
# 's => POS
# State => NNP
# Jewish => NNP
# Chamber => NNP
# Theater => NNP
# are => VBP
# as => IN
# the => DT
# artist => NN
# himself => PRP
# described => VBD
# them => PRP
# his => PRP$
# most => RBS
# important => JJ
# works => NNS
# of => IN
# art => NN
# They => PRP
# express => VBP
# many => JJ
# of => IN
# the => DT
# major => JJ
# influences => NNS
# that => WDT
# formed => VBD
# the => DT
# artist => NN
# 's => POS
# life => NN
# and => CC
# work => NN
# fusing => VBG
# into => IN
# perfect => JJ
# harmony => NN
# his => PRP$
# Jewish => JJ
# and => CC
# Russian => JJ
# background => NN
# and => CC
# traditions => NNS
# with => IN
# European => JJ
# Modern => NNP
# art => NN
# trends => NNS
# Like => IN
# no => DT
# other => JJ
# artist => NN
# ol => IN
# his => PRP$
# time => NN
# Chagall => NNP
# was => VBD
# able => JJ
# to => TO
# combine => VB
# traditional => JJ
# themes => NNS
# with => IN
# Modern => NNP
# painting => VBG
# in => IN
# a => DT
# very => RB
# special => JJ
# and => CC
# symbolic => JJ
# form => NN
# of => IN
# expression => NN
# He => PRP
# thus => RB
# created => VBD
# an => DT
# ensemble => NN
# that => WDT
# contains => VBZ
# its => PRP$
# own => JJ
# message => NN
# for => IN
# and => CC
# language => NN
# of => IN
# the => DT
# different => JJ
# cultures => NNS
# The => DT
# masterpieces => NNS
# were => VBD
# exhibited => VBN
# in => IN
# 1991 => CD
# in => IN
# Frankfurt => NNP
# 's => POS
# Schirn => NNP
# Kunsthalle => NNP
# We => PRP
# are => VBP
# now => RB
# especially => RB
# proud => JJ
# to => TO
# enable => VB
# their => PRP$
# first => JJ
# showing => NN
# in => IN
# America => NNP
# For => IN
# Lufthansa => NNP
# our => PRP$
# traditional => JJ
# commitment => NN
# to => TO
# cultural => JJ
# understanding => NN
# and => CC
# artistic => JJ
# expression => NN
# is => VBZ
# evidenced => VBN
# in => IN
# our => PRP$
# support => NN
# of => IN
# this => DT
# extraordinary => JJ
# exhibition => NN
# Our => PRP$
# association => NN
# with => IN
# great => JJ
# art => NN
# and => CC
# great => JJ
# artists => NNS
# provides => VBZ
# better => JJR
# communication => NN
# across => IN
# different => JJ
# cultures => NNS
# frontiers => NNS
# and => CC
# geographic => JJ
# boundaries => NNS
# It => PRP
# is => VBZ
# after => IN
# all => DT
# what => WP
# Lufthansa => NNP
# is => VBZ
# all => DT
# about => IN
# — => JJ
# linking => VBG
# people => NNS
# with => IN
# people => NNS
# throughout => IN
# the => DT
# world => NN
# This => DT
# exhibition => NN
# in => IN
# particular => JJ
# honors => NNS
# an => DT
# artist => NN
# who => WP
# coined => VBD
# what => WP
# is => VBZ
# perhaps => RB
# the => DT
# most => RBS
# beautiful => JJ
# phrase => NN
# ever => RB
# written => VBN
# about => IN
# art => NN
# Paint => NN
# is => VBZ
# the => DT
# lifeblood => NN
# of => IN
# the => DT
# artist => NN
# — => JJ
# Jiirgen => NNP
# Weber => NNP
# Chairman => NNP
# of => IN
# the => DT
# Executive => NNP
# Board => NNP
# Lufthansa => NNP
# German => NNP
# Airlines => NNPS
# Lufthansa => NNP
# sponsor => NN
# 's => POS
# Statement => NNP
# In => IN
# November => NNP
# 1920 => CD
# the => DT
# State => NNP
# Jewish => NNP
# Chamber => NNP
# Theater => NNP
# moved => VBD
# into => IN
# a => DT
# residence => NN
# in => IN
# Moscow => NNP
# provided => VBN
# by => IN
# the => DT
# Soviet => JJ
# government => NN
# Adjoining => VBG
# rooms => NNS
# on => IN
# the => DT
# second => JJ
# floor => NN
# of => IN
# the => DT
# house => NN
# which => WDT
# had => VBD
# belonged => VBN
# to => TO
# a => DT
# wealthy => JJ
# merchant => NN
# L. => NNP
# I. => NNP
# Gurevich => NNP
# before => RB
# apparently => RB
# being => VBG
# confiscated => VBN
# during => IN
# the => DT
# Revolution => NNP
# were => VBD
# converted => VBN
# into => IN
# a => DT
# small => JJ
# auditorium => NN
# capable => JJ
# of => IN
# seating => VBG
# 90 => CD
# people => NNS
# on => IN
# benches => NNS
# Marc => NNP
# Chagall => NNP
# who => WP
# was => VBD
# by => IN
# then => RB
# known => VBN
# internationally => RB
# was => VBD
# hired => VBN
# to => TO
# design => VB
# the => DT
# sets => NNS
# and => CC
# costumes => NNS
# for => IN
# the => DT
# troupe => NN
# 's => POS
# inaugural => JJ
# production => NN
# of => IN
# three => CD
# one-act => JJ
# plays => NNS
# by => IN
# Sholem => NNP
# Aleichem => NNP
# which => WDT
# opened => VBD
# on => IN
# January => NNP
# i => NN
# 1921 => CD
# In => IN
# the => DT
# last => JJ
# few => JJ
# weeks => NNS
# of => IN
# 1920 => CD
# in => IN
# the => DT
# midst => NN
# of => IN
# civil => JJ
# war => NN
# and => CC
# famine => NN
# the => DT
# artist => NN
# produced => VBD
# an => DT
# ensemble => NN
# of => IN
# paintings => NNS
# for => IN
# the => DT
# theater => NN
# 's => POS
# three => CD
# walls => NNS
# the => DT
# stage => NN
# curtain => NN
# and => CC
# the => DT
# ceiling => NN
# creating => VBG
# an => DT
# environment => NN
# for => IN
# the => DT
# production => NN
# that => WDT
# extended => VBD
# beyond => IN
# the => DT
# stage => NN
# The => DT
# small => JJ
# hall => NN
# became => VBD
# known => VBN
# as => IN
# Chagall => NNP
# 's => POS
# Box => NNP
# Its => PRP$
# surviving => VBG
# seven => CD
# paintings => NNS
# the => DT
# curtain => NN
# and => CC
# ceiling => NN
# canvases => NNS
# were => VBD
# lost => VBN
# form => VBP
# the => DT
# core => NN
# of => IN
# the => DT
# Guggenheim => NNP
# 's => POS
# exhibition => NN
# Marc => NNP
# Chagall => NNP
# and => CC
# the => DT
# Jewish => JJ
# Theater => NNP
# is => VBZ
# designed => VBN
# to => TO
# present => VB
# these => DT
# murals => NNS
# within => IN
# a => DT
# framework => NN
# that => WDT
# illuminates => VBZ
# the => DT
# circumstances => NNS
# of => IN
# their => PRP$
# creation => NN
# from => IN
# Chagall => NNP
# 's => POS
# artistic => JJ
# process => NN
# and => CC
# aesthetic => JJ
# decisions => NNS
# to => TO
# the => DT
# conditions => NNS
# under => IN
# which => WDT
# he => PRP
# worked => VBD
# To => TO
# that => DT
# end => NN
# the => DT
# exhibition => NN
# is => VBZ
# divided => VBN
# into => IN
# two => CD
# components => NNS
# the => DT
# first => JJ
# its => PRP$
# nucleus => NN
# consists => VBZ
# of => IN
# the => DT
# murals => NNS
# and => CC
# related => JJ
# art => NN
# works => NNS
# by => IN
# Chagall => NNP
# Included => VBN
# are => VBP
# studies => NNS
# for => IN
# the => DT
# paintings => NNS
# which => WDT
# demonstrate => VBP
# the => DT
# artist => NN
# 's => POS
# working => VBG
# methods => NNS
# and => CC
# techniques => NNS
# as => RB
# well => RB
# as => IN
# his => PRP$
# set => NN
# and => CC
# costume => JJ
# sketches => NNS
# for => IN
# the => DT
# Sholem => NNP
# Aleichem => NNP
# Evening => NNP
# Also => RB
# on => IN
# display => NN
# are => VBP
# works => VBN
# by => IN
# the => DT
# artist => NN
# in => IN
# the => DT
# Guggenheim => NNP
# 's => POS
# collection => NN
# ranging => VBG
# from => IN
# the => DT
# early => JJ
# Portrait => NN
# of => IN
# the => DT
# Artist => NNP
# 's => POS
# Sister => NNP
# Aniuta => NNP
# 1910 => CD
# cat => NN
# no => DT
# 21 => CD
# painted => VBN
# before => IN
# Chagall => NNP
# made => VBD
# his => PRP$
# pivotal => JJ
# trip => NN
# to => TO
# Paris => NNP
# to => TO
# masterpieces => NNS
# of => IN
# his => PRP$
# first => JJ
# Parisian => JJ
# period => NN
# such => JJ
# as => IN
# Paris => NNP
# Through => IN
# the => DT
# Window => NNP
# 1913 => CD
# cat => NN
# no => DT
# 23 => CD
# to => TO
# important => JJ
# reprises => NNS
# of => IN
# earlier => JJR
# canvases => NNS
# including => VBG
# Green => JJ
# Violinist => NNP
# 1923-24 => JJ
# cat => NN
# no => DT
# 30 => CD
# Chagall => NNP
# created => VBD
# the => DT
# latter => JJ
# painting => NN
# a => DT
# virtual => JJ
# replica => NN
# of => IN
# the => DT
# Jewish => NNP
# Theater => NNP
# 's => POS
# Music => NNP
# 1920 => CD
# cat => NN
# no => DT
# 4 => CD
# in => IN
# Paris => NNP
# from => IN
# a => DT
# sketch => NN
# he => PRP
# had => VBD
# brought => VBN
# with => IN
# him => PRP
# from => IN
# Moscow => NNP
# probably => RB
# the => DT
# drawing => NN
# in => IN
# the => DT
# exhibition => NN
# on => IN
# loan => NN
# from => IN
# the => DT
# Musee => NNP
# national => JJ
# d'art => NN
# moderne => NN
# Centre => NNP
# Georges => NNP
# Pompidou => NNP
# Paris => NNP
# The => DT
# Green => NNP
# Violinist => NNP
# study => NN
# for => IN
# Alz/j/V => NNP
# ] => NNP
# 1920 => CD
# cat => NN
# no => DT
# 11 => CD
# Chagall => DT
# frequently => RB
# re-created => JJ
# images => NNS
# that => IN
# he => PRP
# had => VBD
# painted => VBN
# years => NNS
# before => RB
# as => IN
# if => IN
# to => TO
# have => VB
# souvenirs => NNS
# of => IN
# works => NNS
# that => WDT
# were => VBD
# lost => VBN
# to => TO
# him => PRP
# This => DT
# exhibition => NN
# unites => VBZ
# the => DT
# various => JJ
# versions => NNS
# of => IN
# the => DT
# fiddler => NN
# for => IN
# the => DT
# first => JJ
# time.^ => VBZ
# The => DT
# second => JJ
# component => NN
# of => IN
# the => DT
# exhibition => NN
# is => VBZ
# a => DT
# presentation => NN
# of => IN
# documentary => JJ
# material => NN
# concerning => VBG
# the => DT
# Jewish => JJ
# Theater => NNP
# and => CC
# the => DT
# Chagall => NNP
# commission => NN
# Historical => JJ
# photographs => NN
# sketches => NNS
# and => CC
# posters => NNS
# — => VBP
# some => DT
# unpublished => JJ
# and => CC
# previously => RB
# unknown => JJ
# in => IN
# the => DT
# West => NNP
# — => NN
# and => CC
# explanatory => JJ
# text => NN
# panels => NNS
# indicate => VBP
# the => DT
# period => NN
# and => CC
# atmosphere => NN
# in => IN
# which => WDT
# the => DT
# murals => NNS
# were => VBD
# created => VBN
# One => CD
# section => NN
# is => VBZ
# devoted => VBN
# to => TO
# the => DT
# history => NN
# of => IN
# the => DT
# Jewish => JJ
# Theater => NNP
# from => IN
# its => PRP$
# founding => NN
# in => IN
# 1918 => CD
# through => IN
# 1928 => CD
# Other => JJ
# segments => NNS
# provide => VBP
# background => IN
# information => NN
# on => IN
# Chagall => NNP
# 's => POS
# activities => NNS
# during => IN
# his => PRP$
# second => JJ
# and => CC
# final => JJ
# Russian => JJ
# period => NN
# from => IN
# 1914 => CD
# to => TO
# 1922 => CD
# on => IN
# the => DT
# original => JJ
# installation => NN
# of => IN
# the => DT
# murals => NNS
# and => CC
# on => IN
# the => DT
# history => NN
# of => IN
# the => DT
# paintings => NNS
# after => IN
# their => PRP$
# creation => NN
# I => PRP
# Jennifer => VBP
# Blessing => VBG
# By => IN
# his => PRP$
# own => JJ
# account => NN
# Chagall => NNP
# was => VBD
# determined => VBN
# to => TO
# create => VB
# a => DT
# visual => JJ
# manifesto => NN
# for => IN
# the => DT
# Jewish => JJ
# Theater => NNP
# in => IN
# this => DT
# commission => NN
# Foiled => VBN
# in => IN
# earlier => JJR
# attempts => NNS
# to => TO
# design => VB
# theatrical => JJ
# productions => NNS
# he => PRP
# saw => VBD
# this => DT
# as => IN
# an => DT
# opportunity => NN
# to => TO
# assert => VB
# his => PRP$
# beliefs => NNS
# about => IN
# a => DT
# new => JJ
# direction => NN
# for => IN
# the => DT
# theater => NN
# and => CC
# perhaps => RB
# also => RB
# for => IN
# art => NN
# and => CC
# revolution => NN
# At => IN
# the => DT
# Jewish => JJ
# Theater => NNP
# Chagall => NNP
# found => VBD
# himself => PRP
# among => IN
# a => DT
# group => NN
# of => IN
# young => JJ
# people => NNS
# who => WP
# were => VBD
# trying => VBG
# to => TO
# define => VB
# the => DT
# nature => NN
# of => IN
# their => PRP$
# company => NN
# The => DT
# events => NNS
# of => IN
# 1917 => CD
# had => VBD
# provided => VBN
# a => DT
# tabula => NN
# rasa => NN
# for => IN
# the => DT
# Jewish => JJ
# Theater => NNP
# upon => IN
# which => WDT
# Chagall => NNP
# could => MD
# inscribe => VB
# his => PRP$
# own => JJ
# codes => NNS
# That => DT
# Chagall => NNP
# perceived => VBD
# himself => PRP
# as => IN
# a => DT
# kind => NN
# of => IN
# Moses => NNP
# giving => VBG
# the => DT
# law => NN
# to => TO
# the => DT
# Israelites => NNP
# is => VBZ
# clear => JJ
# in => IN
# his => PRP$
# grand => JJ
# statement => NN
# the => DT
# nearly => RB
# twenty-six-foot-long => JJ
# mural => JJ
# Introduction => NN
# to => TO
# the => DT
# Jewish => JJ
# Theater => NNP
# 1920 => CD
# cat => NN
# no => DT
# i => NN
# in => IN
# which => WDT
# he => PRP
# painted => VBD
# himself => PRP
# being => VBG
# carried => VBN
# by => IN
# Abram => NNP
# Efros => NNP
# the => DT
# theater => NN
# critic => NN
# who => WP
# suggested => VBD
# him => PRP
# for => IN
# the => DT
# commission => NN
# to => TO
# Aleksei => NNP
# Granovskii => NNP
# the => DT
# theater => NN
# 's => POS
# director => NN
# The => DT
# two => CD
# tablets => NNS
# of => IN
# the => DT
# Ten => NNP
# Commandments => NNPS
# appear => VBP
# behind => IN
# the => DT
# artist => NN
# 's => POS
# head => NN
# Through => IN
# a => DT
# natural => JJ
# outgrowth => NN
# of => IN
# his => PRP$
# painterly => JJ
# vocabulary => NN
# Chagall => NNP
# presented => VBD
# a => DT
# kaleidoscopic => NN
# panoply => NN
# of => IN
# ecstatic => JJ
# figures => NNS
# in => IN
# this => DT
# work => NN
# which => WDT
# suggested => VBD
# an => DT
# anti-rational => JJ
# model => NN
# of => IN
# carnivalesque => JJ
# abandon => NN
# for => IN
# the => DT
# theater => NN
# This => DT
# conceptualization => NN
# of => IN
# theater => NN
# was => VBD
# not => RB
# entirely => RB
# new => JJ
# Russian => JJ
# directors => NNS
# such => JJ
# as => IN
# Vsevolod => NNP
# Meierkhol => NNP
# 'd => POS
# and => CC
# Aleksandr => NNP
# Tairov => NNP
# were => VBD
# exploring => VBG
# the => DT
# legacy => NN
# of => IN
# commedia => NN
# dell'arte => NN
# and => CC
# other => JJ
# popular => JJ
# theatrical => JJ
# spectacles => NNS
# before => IN
# Chagall => NNP
# began => VBD
# work => NN
# on => IN
# the => DT
# murals => NNS
# Granovskii => NNP
# was => VBD
# already => RB
# disposed => VBN
# to => TO
# that => DT
# kind => NN
# of => IN
# dramatic => JJ
# treatment => NN
# through => IN
# his => PRP$
# studies => NNS
# under => IN
# Max => NNP
# Reinhardt => NNP
# the => DT
# progressive => JJ
# Austrian => NNP
# director => NN
# Yet => RB
# Chagall => NNP
# presented => VBD
# a => DT
# unique => NN
# and => CC
# uniquely => RB
# Jewish => JJ
# approach => NN
# Through => IN
# specifically => RB
# Jewish => JJ
# visual => JJ
# puns => NN
# Yiddish => JJ
# inscriptions => NNS
# and => CC
# references => NNS
# to => TO
# the => DT
# festivities => NNS
# of => IN
# Jewish => JJ
# weddings => NNS
# and => CC
# Purim => NNP
# — => VBP
# a => DT
# Jewish => JJ
# analogue => NN
# to => TO
# carnival => VB
# in => IN
# its => PRP$
# emphasis => NN
# on => IN
# ludicrous => JJ
# masquerades => NNS
# and => CC
# outrageous => JJ
# intoxication => NN
# — => IN
# he => PRP
# posited => VBD
# a => DT
# distinctive => JJ
# model => NN
# for => IN
# the => DT
# Jewish => JJ
# Theater => NNP
# This => DT
# model => NN
# was => VBD
# not => RB
# without => IN
# political => JJ
# implications => NNS
# In => IN
# a => DT
# 1940 => CD
# paper => NN
# Mikhail => NNP
# Bakhtin => NNP
# 1895-1975 => JJ
# a => DT
# Russian => JJ
# literary => JJ
# scholar => NN
# who => WP
# was => VBD
# Chagall => NNP
# 's => POS
# contemporary => JJ
# described => JJ
# carnival => NN
# as => IN
# a => DT
# populist => NN
# Utopian => JJ
# conception => NN
# of => IN
# the => DT
# world => NN
# ** => NN
# He => PRP
# found => VBD
# a => DT
# critique => NN
# of => IN
# established => VBN
# power => NN
# in => IN
# its => PRP$
# flouting => NN
# of => IN
# conventional => JJ
# behavior => NN
# and => CC
# established => VBD
# ...
# just => RB
# to => TO
# read => VB
# its => PRP$
# title => NN
# This => DT
# gesture => NN
# was => VBD
# enough => RB
# for => IN
# KGB => NNP
# agents => NNS
# to => TO
# start => VB
# following => VBG
# us => PRP
# Although => IN
# it => PRP
# was => VBD
# probably => RB
# only => RB
# someone => NN
# from => IN
# the => DT
# Israeli => NNP
# consulate => NN
# who => WP
# had => VBD
# opened => VBN
# the => DT
# newspaper => NN
# we => PRP
# were => VBD
# closely => RB
# followed => VBN
# for => IN
# three => CD
# days => NNS
# and => CC
# nights => NNS
# After => IN
# that => DT
# I => PRP
# never => RB
# revealed => VBD
# that => IN
# I => PRP
# knew => VBD
# Yiddish => NNP
# Thus => RB
# in => IN
# 1966 => CD
# it => PRP
# was => VBD
# now => RB
# the => DT
# Brezhnev => NNP
# era => NN
# I => PRP
# resisted => VBD
# the => DT
# temptation => NN
# to => TO
# read => VB
# the => DT
# inscriptions => NNS
# on => IN
# Chagall => NNP
# 's => POS
# murals => NNS
# for => IN
# my => PRP$
# colleagues => NNS
# Several => JJ
# months => NNS
# later => RB
# after => IN
# the => DT
# Arab => JJ
# armies => NNS
# who => WP
# were => VBD
# equipped => VBN
# by => IN
# the => DT
# Soviets => NNPS
# suffered => VBD
# a => DT
# crushing => VBG
# defeat => NN
# in => IN
# the => DT
# Six-Day => NNP
# War => NNP
# with => IN
# Israel => NNP
# the => DT
# Kremlin => NNP
# geared => VBD
# up => RP
# its => PRP$
# propaganda => NN
# machine => NN
# in => IN
# a => DT
# desperate => JJ
# anti- => JJ
# Zionist => NNP
# campaign => NN
# Newspapers => NNS
# magazines => NNS
# television => NN
# and => CC
# radio => NN
# proclaimed => VBD
# the => DT
# Zionists => NNS
# ' => POS
# subversive => JJ
# activities => NNS
# numerous => JJ
# books => NNS
# about => IN
# the => DT
# threat => NN
# of => IN
# Zionism => NNP
# were => VBD
# published => VBN
# and => CC
# printed => VBN
# in => IN
# large => JJ
# runs => NNS
# The => DT
# tactics => NNS
# were => VBD
# designed => VBN
# to => TO
# incite => VB
# anti-Semitism => NN
# and => CC
# to => TO
# put => VB
# pressure => NN
# on => IN
# and => CC
# demonstrate => VB
# hostility => NN
# toward => IN
# Jews => NNP
# The => DT
# Soviets => NNPS
# had => VBD
# kept => VBN
# silent => JJ
# about => IN
# Chagall => NNP
# 's => POS
# existence => NN
# since => IN
# he => PRP
# had => VBD
# left => VBN
# Russia => NNP
# more => JJR
# than => IN
# fifty => CD
# years => NNS
# earlier => RBR
# In => IN
# the => DT
# early => JJ
# 1970s => CD
# I => PRP
# came => VBD
# across => IN
# Chagall => NNP
# 's => POS
# name => NN
# in => IN
# one => CD
# of => IN
# those => DT
# contemptible => JJ
# books => NNS
# among => IN
# the => DT
# names => NNS
# of => IN
# those => DT
# who => WP
# had => VBD
# sympathized => VBN
# with => IN
# Israel => NNP
# He => PRP
# was => VBD
# identified => VBN
# as => IN
# the => DT
# bard => NN
# of => IN
# Zionism. => NNP
# In => IN
# the => DT
# spring => NN
# of => IN
# 1973 => CD
# I => PRP
# was => VBD
# summoned => VBN
# to => TO
# a => DT
# meeting => NN
# at => IN
# the => DT
# Ministry => NNP
# of => IN
# Culture => NNP
# of => IN
# the => DT
# USSR => NNP
# at => IN
# which => WDT
# I => PRP
# was => VBD
# informed => VBN
# that => IN
# Chagall => NNP
# himself => PRP
# was => VBD
# coming => VBG
# to => TO
# Moscow => NNP
# and => CC
# at => IN
# which => WDT
# the => DT
# mounting => NN
# of => IN
# some => DT
# kind => NN
# of => IN
# exhibition => NN
# during => IN
# his => PRP$
# visit => NN
# was => VBD
# proposed => VBN
# The => DT
# head => NN
# of => IN
# the => DT
# Department => NNP
# of => IN
# Culture => NNP
# of => IN
# the => DT
# Central => NNP
# Committee => NNP
# of => IN
# the => DT
# Communist => NNP
# Party => NNP
# of => IN
# the => DT
# Soviet => NNP
# Union => NNP
# who => WP
# was => VBD
# at => IN
# the => DT
# meeting => NN
# did => VBD
# not => RB
# conceal => VB
# his => PRP$
# contempt => NN
# when => WRB
# Chagall => NNP
# was => VBD
# mentioned => VBN
# With => IN
# the => DT
# exception => NN
# of => IN
# its => PRP$
# appearance => NN
# in => IN
# the => DT
# anti-Zionist => JJ
# publication => NN
# discussed => VBN
# above => IN
# his => PRP$
# name => NN
# it => PRP
# seemed => VBD
# had => VBD
# actually => RB
# been => VBN
# forgotten => VBN
# until => IN
# that => DT
# time => NN
# Afterword => NNP
# \ => VBZ
# 20 => CD
# ^'^f^ => NN
# *ir^M => JJ
# » => NNP
# m => NN
# Marc => NNP
# Chagall => NNP
# — => NNP
# surrounded => VBN
# by => IN
# from => IN
# left => VBN
# to => TO
# right => VB
# A. => NN
# P. => NNP
# Kovalev => NNP
# L. => NNP
# I. => NNP
# Romashkoi'a => NNP
# Gregory => NNP
# Veitsman => NNP
# V. => NNP
# M. => NNP
# Volodarskii => NNP
# L. => NNP
# Lifshitz => NNP
# and => CC
# P. => NNP
# I. => NNP
# Lebedev => NNP
# — => NNP
# as => IN
# he => PRP
# signed => VBD
# Introduction => NNP
# to => TO
# the => DT
# Jewish => JJ
# Theater => NNP
# // => CC
# the => DT
# State => NNP
# Tret'iakoi => NNP
# ' => POS
# Gallery => NNP
# in => IN
# 1973 => CD
# Photo => NNP
# courtesy => NN
# Gregory => NNP
# Veitsman => NNP
# 206 => CD
# Gregory => NNP
# Veitsman => NNP
# On => IN
# June => NNP
# 5 => CD
# rooms => NNS
# 17A => CD
# and => CC
# 17B => CD
# were => VBD
# closed => VBN
# off => RB
# from => IN
# the => DT
# rest => NN
# of => IN
# the => DT
# museum => NN
# and => CC
# an => DT
# exhibition => NN
# of => IN
# sixty-three => NN
# of => IN
# Chagall => NNP
# 's => POS
# lithographs => NN
# was => VBD
# hung => NN
# No => DT
# announcement => NN
# ot => VBZ
# the => DT
# day => NN
# or => CC
# time => NN
# of => IN
# his => PRP$
# visit => NN
# to => TO
# the => DT
# Tret'iakov => NNP
# had => VBD
# been => VBN
# made => VBN
# but => CC
# a => DT
# crowd => NN
# gathered => VBN
# in => IN
# the => DT
# side => NN
# streets => VBZ
# around => IN
# the => DT
# museum => NN
# Three => CD
# rows => NNS
# of => IN
# policemen => NNS
# prevented => VBN
# anyone => NN
# from => IN
# approaching => VBG
# Chagall => NNP
# He => PRP
# his => PRP$
# wife => NN
# Vava => NNP
# and => CC
# Nadia => NNP
# Leger => NNP
# were => VBD
# not => RB
# brought => VBN
# in => IN
# through => IN
# the => DT
# main => JJ
# gates => NNS
# but => CC
# by => IN
# a => DT
# service => NN
# entrance => NN
# They => PRP
# came => VBD
# up => RB
# to => TO
# the => DT
# Director => NNP
# 's => POS
# study => NN
# on => IN
# the => DT
# second => JJ
# floor => NN
# for => IN
# a => DT
# champagne => NN
# toast => NN
# and => CC
# then => RB
# walked => VBD
# through => IN
# the => DT
# library => NN
# to => TO
# rooms => NNS
# 17A => CD
# and => CC
# 17B => CD
# Chagall => NNP
# went => VBD
# first => RB
# escorted => VBN
# by => IN
# Minister => NNP
# of => IN
# Culture => NNP
# E. => NNP
# A. => NN
# Furtseva => NNP
# Director => NNP
# Lebedev => NNP
# and => CC
# several => JJ
# other => JJ
# officials => NNS
# With => IN
# 'Vava => NNP
# holding => VBG
# my => PRP$
# arm => NN
# she => PRP
# and => CC
# I => PRP
# followed => VBD
# a => DT
# few => JJ
# steps => NNS
# behind => IN
# 1 => CD
# was => VBD
# observing => VBG
# Chagall => NNP
# who => WP
# was => VBD
# smartly => RB
# dressed => VBN
# and => CC
# looked => VBN
# magnificent => NN
# He => PRP
# seemed => VBD
# quite => RB
# happy => JJ
# and => CC
# excited => JJ
# and => CC
# was => VBD
# cordial => JJ
# to => TO
# all => DT
# We => PRP
# went => VBD
# upstairs => NNS
# to => TO
# the => DT
# Repin => NNP
# room => NN
# and => CC
# then => RB
# to => TO
# the => DT
# galleries => NNS
# where => WRB
# the => DT
# lithographs => NN
# were => VBD
# displayed => VBN
# They => PRP
# were => VBD
# not => RB
# even => RB
# framed => VBN
# but => CC
# under => IN
# glass => NN
# in => IN
# cases => NNS
# that => WDT
# had => VBD
# been => VBN
# slapped => VBN
# together => RB
# for => IN
# the => DT
# occasion => NN
# The => DT
# entire => JJ
# viewing => NN
# lasted => VBD
# only => RB
# a => DT
# very => RB
# short => JJ
# time => NN
# It => PRP
# was => VBD
# packed => VBN
# with => IN
# KGB => NNP
# agents => NNS
# there => EX
# were => VBD
# no => DT
# members => NNS
# of => IN
# the => DT
# press => NN
# present => JJ
# except => IN
# for => IN
# the => DT
# Paris-Match => NNP
# correspondent => NN
# at => IN
# Chagall => NNP
# 's => POS
# personal => JJ
# request => NN
# The => DT
# sculptor => NN
# I. => NNP
# M. => NNP
# Chaikov => NNP
# pushed => VBD
# his => PRP$
# way => NN
# through => IN
# the => DT
# crowd => NN
# to => TO
# me => PRP
# and => CC
# started => VBD
# lamenting => VBG
# how => WRB
# quickly => RB
# the => DT
# years => NNS
# had => VBD
# flown => VBN
# by => IN
# He => PRP
# recalled => VBD
# the => DT
# time => NN
# of => IN
# his => PRP$
# youth => NN
# when => WRB
# he => PRP
# and => CC
# Chagall => NNP
# had => VBD
# worked => VBN
# and => CC
# exhibited => VBN
# together => RB
# in => IN
# Berlin => NNP
# We => PRP
# were => VBD
# waiting => VBG
# for => IN
# the => DT
# viewing => NN
# to => TO
# end => VB
# when => WRB
# Chagall => NNP
# came => VBD
# over => RB
# a => DT
# museum => NN
# photographer => NN
# captured => VBD
# the => DT
# touching => VBG
# meeting => NN
# of => IN
# the => DT
# two => CD
# former => JJ
# students => NNS
# as => IN
# I => PRP
# stood => VBD
# between => IN
# them => PRP
# When => WRB
# Chagall => NNP
# came => VBD
# to => TO
# the => DT
# museum => NN
# again => RB
# on => IN
# June => NNP
# 8 => CD
# to => TO
# see => VB
# the => DT
# GOSEKT => NNP
# panels => NNS
# I => PRP
# handed => VBD
# him => PRP
# the => DT
# photograph => NN
# which => WDT
# he => PRP
# kindly => RB
# signed => VBD
# with => IN
# the => DT
# date => NN
# 8/6 => CD
# 1973 => CD
# his => PRP$
# name => NN
# Chagall => NN
# in => IN
# French => NNP
# and => CC
# the => DT
# place => NN
# Moscow => NNP
# in => IN
# Russian => NNP
# On => IN
# this => DT
# second => JJ
# visit => NN
# Chagall => NNP
# seemed => VBD
# more => JJR
# at => IN
# ease => NN
# The => DT
# moment => NN
# we => PRP
# entered => VBD
# room => NN
# 21 => CD
# the => DT
# Valentin => NNP
# Serov => NNP
# room => NN
# where => WRB
# all => DT
# of => IN
# Chagall => NNP
# 's => POS
# huge => JJ
# murals => NNS
# for => IN
# the => DT
# Jewish => JJ
# Theater => NNP
# were => VBD
# unrolled => VBN
# on => IN
# the => DT
# floor => NN
# he => PRP
# grew => VBD
# quiet => JJ
# I => PRP
# saw => VBD
# delight => NN
# and => CC
# astonishment => NN
# in => IN
# his => PRP$
# face => NN
# We => PRP
# — => VBP
# there => EX
# were => VBD
# only => RB
# a => DT
# few => JJ
# people => NNS
# in => IN
# the => DT
# room => NN
# — => NN
# stood => VBD
# to => TO
# one => CD
# side => NN
# while => IN
# Chagall => NNP
# walked => VBD
# back => RB
# and => CC
# forth => JJ
# beside => IN
# the => DT
# painted => JJ
# canvases => NNS
# spread => VBP
# out => RP
# on => IN
# the => DT
# floor => NN
# the => DT
# works => NNS
# that => IN
# he => PRP
# had => VBD
# created => VBN
# more => RBR
# than => IN
# a => DT
# half-century => NN
# before => IN
# His => PRP$
# eyes => NNS
# shone => NN
# and => CC
# he => PRP
# was => VBD
# silent => JJ
# for => IN
# a => DT
# few => JJ
# minutes => NNS
# before => IN
# saying => VBG
# something => NN
# quietly => RB
# to => TO
# himself => PRP
# Then => RB
# he => PRP
# drew => VBD
# himself => PRP
# up => RP
# proudly => RB
# as => IN
# if => IN
# to => TO
# communicate => VB
# Look => VB
# / => RB
# created => VBD
# this => DT
# He => PRP
# started => VBD
# to => TO
# say => VB
# something => NN
# about => IN
# how => WRB
# nice => JJ
# it => PRP
# would => MD
# be => VB
# to => TO
# exhibit => VB
# the => DT
# murals => NNS
# and => CC
# that => IN
# he => PRP
# was => VBD
# glad => JJ
# they => PRP
# were => VBD
# still => RB
# together => RB
# and => CC
# had => VBD
# been => VBN
# so => RB
# well => RB
# preserved => VBN
# After => IN
# a => DT
# short => JJ
# discussion => NN
# it => PRP
# was => VBD
# decided => VBN
# he => PRP
# should => MD
# sign => VB
# the => DT
# murals => NNS
# Brushes => NNS
# and => CC
# paint => NN
# were => VBD
# brought => VBN
# in => IN
# along => IN
# with => IN
# a => DT
# chair => NN
# Chagall => NNP
# sat => VBD
# down => RB
# laid => VBD
# a => DT
# corner => NN
# of => IN
# a => DT
# canvas => NN
# on => IN
# a => DT
# drum => NN
# and => CC
# began => VBD
# to => TO
# sign => VB
# them => PRP
# not => RB
# knowing => VBG
# which => WDT
# language => NN
# it => PRP
# would => MD
# be => VB
# best => RBS
# to => TO
# use => VB
# but => CC
# finally => RB
# deciding => VBG
# on => IN
# Russian => NNP
# Vava => NNP
# called => VBD
# to => TO
# him => PRP
# from => IN
# the => DT
# other => JJ
# end => NN
# of => IN
# the => DT
# room => NN
# Chagall => NNP
# engrossed => VBD
# in => IN
# his => PRP$
# beloved => JJ
# murals => NNS
# did => VBD
# not => RB
# even => RB
# hear => VB
# although => IN
# he => PRP
# did => VBD
# say => VB
# something => NN
# to => TO
# her => PRP$
# like => NN
# What => WP
# a => DT
# good => JJ
# artist => NN
# I => PRP
# am => VBP
# And => CC
# then => RB
# he => PRP
# began => VBD
# dreaming => VBG
# aloud => NN
# about => IN
# exhibiting => VBG
# them => PRP
# displaying => VBG
# them => PRP
# there => EX
# at => IN
# the => DT
# museum => NN
# in => IN
# Russia => NNP
# While => IN
# glancing => VBG
# at => IN
# Lebedev => NNP
# who => WP
# was => VBD
# maintaining => VBG
# a => DT
# careful => JJ
# official => JJ
# expression => NN
# and => CC
# then => RB
# at => IN
# one => CD
# KGB => NNP
# agent => NN
# and => CC
# another => DT
# KGB => NNP
# agent => NN
# I => PRP
# remembered => VBD
# the => DT
# words => NNS
# in => IN
# that => DT
# anti-Zionist => JJ
# book => NN
# calling => VBG
# Chagall => NNP
# the => DT
# bard => NN
# of => IN
# Zionism. => NNP
# Indeed => RB
# the => DT
# time => NN
# when => WRB
# the => DT
# murals => NNS
# for => IN
# the => DT
# Jewish => JJ
# Theater => NNP
# could => MD
# be => VB
# exhibited => VBN
# was => VBD
# distant => JJ
# The => DT
# day => NN
# after => IN
# the => DT
# departure => NN
# of => IN
# Chagall => NNP
# who => WP
# was => VBD
# hurrying => VBG
# back => RB
# to => TO
# France => NNP
# for => IN
# the => DT
# opening => NN
# of => IN
# the => DT
# museum => NN
# dedicated => VBN
# to => TO
# him => PRP
# we => PRP
# were => VBD
# obliged => VBN
# to => TO
# take => VB
# down => RP
# everything => NN
# connected => VBN
# with => IN
# him => PRP
# and => CC
# hide => VB
# it => PRP
# in => IN
# the => DT
# storeroom => NN
# once => RB
# again => RB
# Many => JJ
# years => NNS
# later => RB
# in => IN
# the => DT
# early => JJ
# 1980s => CD
# I => PRP
# spoke => VBD
# with => IN
# Marc => NNP
# and => CC
# Vava => NNP
# at => IN
# their => PRP$
# home => NN
# in => IN
# St. => NNP
# Paul => NNP
# de => FW
# Vence => NNP
# He => PRP
# remembered => VBD
# every => DT
# single => JJ
# detail => NN
# about => IN
# the => DT
# visit => NN
# to => TO
# Moscow => NNP
# He => PRP
# asked => VBD
# me => PRP
# if => IN
# I => PRP
# remembered => VBD
# how => WRB
# Furtseva => NNP
# the => DT
# Minister => NNP
# of => IN
# Culture => NNP
# repeatedly => RB
# asked => VBD
# him => PRP
# not => RB
# to => TO
# speak => VB
# ill => NN
# of => IN
# the => DT
# Soviet => NNP
# Union => NNP
# and => CC
# the => DT
# Communist => JJ
# government => NN
# With => IN
# twinkling => VBG
# eyes => NNS
# he => PRP
# said => VBD
# And => CC
# why => WRB
# were => VBD
# they => PRP
# so => RB
# certain => JJ
# that => IN
# there => EX
# was => VBD
# anything => NN
# bad => JJ
# to => TO
# say => VB
# about => IN
# them => PRP
# After => IN
# a => DT
# brief => JJ
# pause => NN
# he => PRP
# continued => VBD
# Of => IN
# course => NN
# they => PRP
# destroyed => VBD
# such => PDT
# a => DT
# rich => JJ
# beautiful => JJ
# Jewish => JJ
# culture => NN
# Perestroika => NNP
# and => CC
# the => DT
# fall => NN
# of => IN
# the => DT
# Soviet => JJ
# empire => NN
# were => VBD
# yet => RB
# to => TO
# come => VB
# I => PRP
# know => VBP
# how => WRB
# happy => JJ
# Chagall => NNP
# would => MD
# have => VB
# been => VBN
# to => TO
# see => VB
# the => DT
# murals => NNS
# exhibited => VBN
# in => IN
# New => NNP
# York => NNP
# — => NN
# Translated => NNP
# from => IN
# the => DT
# Russian => NNP
# by => IN
# Judith => NNP
# Vowles => NNP
# Aftenivrd => NNP
# \ => VBD
# 20 => CD
# The => DT
# Solomon => NNP
# R. => NNP
# Guggenheim => NNP
# Foundation => NNP
# Honorary => NNP
# Trustees => NNP
# in => IN
# Perpetuity => NNP
# Solomon => NNP
# R. => NNP
# Guggenheim => NNP
# Justin => NNP
# K. => NNP
# Thannhauser => NNP
# Peggy => NNP
# Guggenheim => NNP
# President => NNP
# Peter => NNP
# Lawson-Johnston => NNP
# Vice-Presidents => NNP
# The => DT
# Right => NNP
# Honorable => NNP
# Earl => NNP
# Castle => NNP
# Stewart => NNP
# Wendy => NNP
# L-J => NNP
# McNeil => NNP
# Robert => NNP
# M. => NNP
# Gardiner => NNP
# Director => NNP
# Thomas => NNP
# Krens => NNP
# Trustees => VBZ
# The => DT
# Right => NNP
# Honorable => NNP
# Earl => NNP
# Castle => NNP
# Stewart => NNP
# Mary => NNP
# Sharp => NNP
# Cronson => NNP
# Elaine => NNP
# Dannheisser => NNP
# Michel => NNP
# A. => NNP
# David-Weill => NNP
# Carlo => NNP
# De => NNP
# Benedetti => NNP
# The => DT
# Honorable => NNP
# Gianni => NNP
# De => NNP
# Michelis => NNP
# Robin => NNP
# Chandler => NNP
# Duke => NNP
# Robert => NNP
# M. => NNP
# Gardiner => NNP
# Jacques => NNP
# Hachuel => NNP
# Moreno => NNP
# Rainer => NNP
# Heubach => NNP
# Barbara => NNP
# Jonas => NNP
# Thomas => NNP
# Krens => NNP
# Peter => NNP
# Lawson-Johnston => NNP
# Arthur => NNP
# Levitt => NNP
# Jr. => NNP
# Wendy => NNP
# L-J => NNP
# McNeil => NNP
# Edward => NNP
# H. => NNP
# Meyer => NNP
# Michael => NNP
# M. => NNP
# Rea => NNP
# Denise => NNP
# Saul => NNP
# William => NNP
# A. => NNP
# Schreyer => NNP
# James => NNP
# B. => NNP
# Sherwood => NNP
# Raja => NNP
# Sidawi => NNP
# Seymour => NNP
# Slive => NNP
# Peter => NNP
# W. => NNP
# Stroh => NNP
# Stephen => NNP
# C. => NNP
# Swid => NNP
# Rawleigh => NNP
# Warner => NNP
# Jr. => NNP
# Jiirgen => NNP
# Weber => NNP
# Michael => NNP
# F. => NNP
# Wettach => NNP
# Donald => NNP
# M. => NNP
# Wilson => NNP
# William => NNP
# T => NNP
# Ylvisaker => NNP
# Honorary => NNP
# Trustee => NNP
# Claude => NNP
# Pompidou => NNP
# Trustee => NNP
# Ex => NNP
# Officio => NNP
# Roberto => NNP
# Tronchetti => NNP
# Provera => NNP
# Director => NNP
# Emeritus => NNP
# Thomas => NNP
# M. => NNP
# Messer => NNP

# %% [markdown]
# ### Noun Phrase Extraction
# Noun phrase extraction, as the name suggests, refers to extracting phrases that contain nouns. Let's find all the noun phrases in the first paragraph of the Wikipedia article on artificial intelligence that we used earlier.
#
# To find noun phrases, you simply have to use the noun_phrase attributes on the TextBlob object. Look at the following example:

# %%
for noun_phrase in text_blob_object.noun_phrases:  
    print(noun_phrase)
# Out:
# guggenheim museum digitized
# internet arciiive
# ivietropolitan
# york
# library council
# metro
# marc chagall
# jevs^ish
# marc chagall
# jevn^ish
# guggenheim museum
# solomon r. guggenheim
# york
# reproductions
# © state
# tret'iakov
# moscow marc chagall
# je
# vish theater
# solomon r. guggenheim
# september
# art
# chicago january
# isbn
# guggenheim
# york
# york
# prmted
# thorner
# front
# marc chagall
# m/isk
# tempera
# i03-5
# v4
# tret'iakov
# moscow
# marc chagall
# loi'e
# tempera
# 7s x
# 'a inches
# tret'iakov
# moscow frontispiece
# emblem
# jewish chamber theater
# petrograd
# color
# cat
# tret'iakov
# moscow
# h. preisig
# fondation pierre gianadda
# lee ewing
# cat
# musee
# national d'art moderne
# centre georges pompidou
# paris
# philippe migeat
# centre g. pompidou
# cat
# ida chagall
# paris
# cat
# solomon r. guggenheim
# myles aronowitz
# lee ewing
# carmelo guadagno
# david heald
# lufthansa
# lufthansa additional
# helena rubinstein
# marc chagall
# jewish theater
# contents preface thomas krens
# fore
# vord h/rii
# k. korolev x sponsor
# statement
# weber
# introduction jeiuujer bleising
# chagall
# 's auditorium
# identity crisis
# tragic dimensions
# s/i.saii
# odiptoii
# chagall
# postmodernism
# fictional worlds
# painting benjamin harshav
# catalogue
# texts
# documents edited
# benjamin harshav translated
# benjamin
# barbara harshav
# bibliography benjamin harshav
# aftervs^ord gregory veitsman
# alan- chagall
# jewish theater
# gu^'genheim
# soho
# utopia
# r/issian
# avant-garde
# ipi $ -ip^2
# comprehensive exhibition
# modernist
# twentieth century
# solomon r. guggenheim
# utopia
# fruits ot
# avant-garde 's attempt
# entire society —
# tremendous political upheaval
# revolution
# artists
# integral participants
# formation ol
# soviet government
# new forms
# utilitarian objects
# stranded
# russia
# world war
# marc chagall
# tremendous asset
# crucial moments
# carmen gimenez
# curator
# twentieth-century art
# loan negotiations
# jane sharp
# project associate curator
# utopia
# chagall
# sharon corwin
# curatorial intern
# numerous problems
# short summer tenure
# technical
# pamela myers
# exhibitions
# programming
# short months
# peter costa
# senior
# technician
# andrew
# simons
# associate designer
# didactic component
# massimo vignelli
# publications
# anthony calnek
# editor
# mr. calnek
# laura morris
# editor
# jennifer knox
# editorial
# good spirits
# paul schwartzbaum
# assistant director
# technical
# conservator
# technical issues
# jan adlmann
# programs
# lectures/new insights
# marc chagall
# jewish theater
# project
# 92nd street
# staff members
# lynne addison
# associate registrar
# exhibition midstream
# heidi rosenau
# coordinator
# chagall
# catalogue 's contributors
# short deadlines
# susan compton
# chagall
# benjamin harshav
# j.
# h. blaustein professor
# hebrew
# comparative literature
# yale
# immeasurable contributions
# chagall
# barbara harshav
# harshav
# extensive selection
# primary texts
# gregory veitsman
# assistant director
# technical
# tret'iakov
# chagall
# thomas krens
# solomon r. guggenheim
# preface
# acknowhdgimnti
# forevn^ord
# monumental murals
# marc chagall
# jewish chamber theater
# moscow
# gosekt
# native land
# artistic achievement
# art scholars
# tret'iakov
# country 's
# permanent collection
# large size
# infrequent basis
# paint layers
# tret'iakov
# careful treatment
# late 1960s
# museum 's
# old exhibition galleries
# museum underwent major reconstruction
# exhibition space
# such works
# chagall
# 's theater panels
# vrubel
# 's panel
# priucess gnzci
# singular history
# chagall
# 's murals —
# extreme conditions
# russia
# thin linen
# subsequent fate
# dramatic twists
# theater 's
# bol'shoi chernyshevskii
# malaia bronnaia
# far- from-ideal storage conditions
# war —
# weak threads
# large areas
# chagall
# 's canvas
# tret'iakov
# gallery 's restorers
# aleksei kovalev
# unique method
# leonid astaf
# galina
# restoration project
# international collaboration
# various countries
# high quality
# ferrara
# extensive exhibition tour
# switzerland
# fondation pierre gianadda
# martigny
# schirn kunsthalle frankfurt
# tret'iakov
# moscow
# russian museum
# petersburg
# chagall
# russian period
# america
# york
# foreword
# distant place
# profound thanks
# thomas krens
# solomon r. guggenheim
# deputy director
# michael govan
# marc chagall
# jewish theater
# nicolas v. iljine
# lufthansa
# enormous interest
# chagall
# 's legendary panels
# great works
# monumental scale
# russia
# — lurii
# k. korolev
# general director state
# tret'iakov
# moscow sponsor'is statement
# monumental murals
# chagall
# moscow
# 's state
# jewish chamber theater
# important works
# major influences
# artist 's life
# perfect harmony
# russian background
# european modern art trends
# artist ol
# chagall
# traditional themes
# modern painting
# symbolic form
# own message
# different cultures
# frankfurt
# schirn kunsthalle
# america
# lufthansa
# traditional commitment
# cultural understanding
# artistic expression
# extraordinary exhibition
# great art
# great artists
# different cultures
# geographic boundaries
# lufthansa
# particular honors
# beautiful phrase
# paint
# jiirgen weber
# executive board
# lufthansa
# lufthansa
# statement
# november
# jewish chamber theater
# moscow
# soviet government
# adjoining
# wealthy merchant
# l. i. gurevich
# revolution
# small auditorium
# marc chagall
# troupe 's inaugural production
# sholem aleichem
# january
# civil war
# theater 's
# stage curtain
# university press
# bakhtin
# grotesque bodies
# vertical paintings
# chagall
# tiny vignettes reveals
# small figure
# painting music
# margit rowell
# qui fait caca
# itinerant players
# purim
# kampf
# purim
# art
# stage design
# quest
# style
# amishai-maisels
# chagall
# murals
# jewish chamber theatre
# chagall
# introduction
# jewish theater
# purim
# amishai-maisels
# chagall
# murals
# jewish chamber theatre
# chagall
# 'le cirque
# moi c'est
# enorme realite
# nous
# somme tous des personnages des cirque
# quoted
# rudenstine
# guggenheim
# collection
# paintings
# amishai-maisels
# chagall
# murals
# jewish chamber theatre
# wedding canopy
# love
# quoted
# nahma sandrow
# yiddish
# theaters
# goset
# vagabond
# history
# yiddish
# york
# harper
# gregory
# veitsman
# assistant director
# technical
# tret'iakov
# afterword
# restoration
# fondation pierre gianadda
# martigny
# switzerland
# fondation pierre gianadda
# march
# schirn kunsthalle frankfurt
# june
# tret'iakov
# moscow
# fall 1991-winter
# russian museum
# petersburg
# dance
# tret'iakov
# moscow
# bunkamura
# art
# tokyo
# kasama nichido
# ibaraki
# nagoya
# city art museum
# introduction
# r # y-i ^^ /v1
# chagalps
# identity crisis
# tragic dimensions'^ susan compton
# chagall
# introduction
# jewish theater { cat
# whole auditorium
# marc chagall
# november-december
# moscow
# spectacular setting
# jewish chamber theater
# yiddish
# traditional language
# jews
# europe
# suitable premises
# petrograd
# bol'shoi chernyshevskii
# moscow
# jewish theater company
# april
# moscow
# november
# new space
# sholem aleichem
# chagall
# new year 's day
# abram efros
# artistic director
# efros
# art
# marc chagall
# chagall
# 's role
# jewish chamber theater
# artist 's
# own memoirs
# lifej
# chagall
# vivid account
# paintings —
# canvas —
# vertical panels
# dance
# drama
# literature
# narrow frieze
# wedding feast
# long composition
# introduction
# jewish theater
# windowless wall
# love
# entrance doors
# stage curtain
# james johnson sweeney
# interwoven pattern
# original setting
# new home
# jewish chamber theater
# concert hall
# malaia bronnaia
# old theater
# chagall
# large works
# new building
# chagall
# 's lifetime
# theater decorations
# photographs —
# paris
# europe
# late 1920s
# sholem aleichem evening
# malaia bronnaia
# tangible reminder
# york
# violinist
# chagall
# violinist
# paris
# guggenheim
# museum 's collection
# artist 's possession
# chagall
# 's auditorium
# york
# chagall
# 's retrospective
# art
# jewish chamber theater
# watercolor study
# introduction
# jewish theater
# moscow
# stalin
# jews
# aleksandr tyshler
# chagall
# 's canvases
# tret'iakov
# chagall
# tret'iakov
# moscow
# chagall
# conservation work
# forty years
# present exhibition
# chagall
# 's theater murals
# own art
# ideas
# chagall
# 's life
# vitebsk
# certain aspects
# yiddish-
# previously
# chagall
# 's memoirs
# objective account
# chagall
# russian
# vasilii kandinskii
# reminiscences^
# artist 's
# artistic autobiography
# chagall
# 's art
# bella
# childhood background
# chagall
# original primitive
# apparent naivete
# chagall
# 's sophistication
# decorative scheme
# jewish chamber theater
# pictorial space
# individual parts
# complete work
# decorative schemes
# russian
# berlin
# kandinskii
# chagall
# art
# vitebsk
# ivan puni
# jean pougny
# el lissitzky
# venice biennale
# environmental art
# twentieth century
# puni
# der sturm
# berlin
# puni
# gallery walls
# lissitzky
# proun
# grosser berliner kunstausstellung
# three- dimensional
# kandinskii
# musical environment
# berlin
# huge murals
# abstract elements
# contemporary paintings
# black background
# octagonal room
# berlin
# chagall
# moscow
# chagall
# moscow
# russian artists
# berlin
# lesser extent
# puni
# lissitzky
# kandinskii
# chagall
# abstract elements
# narrow path
# ... abstract art
# cubists
# sei/lement
# nous [
# chagall
# 's design
# imaginary world
# chagall
# 's plan
# stage performance
# introduction
# jewish theater
# long wall
# stage curtain
# lively mural
# an-ski
# dybbuk
# love
# exit wall
# chagall
# 's theater
# avant-garde artists
# artistic life
# petrograd
# moscow
# chagall
# stray dog
# comedian 's
# halt
# pittoresque
# poets
# moscow
# comedian 's
# halt
# large figure paintings
# boris grigorev
# chagall
# theatrical productions
# musical sketch
# die happy
# chagall
# nikolai evreinov
# chagall
# meyerhold.
# author 's reason
# evreinov
# vsevolod meierkhol
# chagall
# evreinov
# comedian 's
# halt
# nikolai gogol
# chagall
# meierkhol'd
# hermitage
# studio theater
# chagall
# theatrical camp
# konstantin stanislavskii
# moscow art
# realistic style
# chagall
# evreinov
# own ideas
# old time theater
# petersburg
# chagall
# frequent debates
# russian
# chagall
# zvantseva
# lev bakst
# sergei diaghilev
# 's ballets
# petersburg
# paris
# mstislav dobuzhinskii
# chagall
# medieval mystery
# evreinov
# naturalistic ones
# stanislavskii
# 's production
# month
# susan comlhon chagall
# early interest
# dobuzhinskii
# 's name
# long aher
# dobuzhinskii
# early productions ot
# jewish chamber theater
# art
# vitebsk
# bakst
# narcisse
# chagall
# 's mural
# dance
# bakst
# 's costume designs
# bacchantes
# nanisse
# chagall
# 's failure
# evreinov
# director 's ideas
# chagall
# 's approach
# evreinov
# 's ideas
# evreinov
# theatrical principles
# chagall
# frequent choice
# dramatic moments
# everyday life
# subject matter
# evreinov
# primitive man guards
# everyday life
# such events
# small psychological step
# dismissing
# theatrical illusion
# actual subject
# » i
# own spiritual values
# external idea
# pure
# pure symbolism
# true theater —
# duplicates life
# direct enjoyment
# chagall
# different non-naturalistic styles
# zvantseva
# paris
# dead
# school 's exhibition
# apollon
# birth
# wedding
# jewish chamber theater murals
# paul gauguin
# chagall
# 's attraction
# such subjects
# real symbols
# viacheslav ivanov
# tower
# top floor
# zvantseva
# ivanov
# everyday things
# empirical consciousness
# ivanov
# midwife eases
# artist }
# chagall
# central figure
# newborn child
# chagall
# 's approach
# evreinov
# 's ideas
# drunkard
# comedian 's
# halt
# right ambience
# russian
# theater design
# great care
# rare case
# chagall
# 's backdrop
# jewish chamber theater
# paris
# drunkard
# new ideas
# petersburg
# paris
# international stature
# version o {
# wedding
# wedding
# friezelike composition
# stagelike space
# abstract shapes
# brilliant hues
# paris
# new version
# birth
# own episode
# russia
# mir iskusstva
# art
# vitebsk
# june
# chagall
# french artists
# henri
# fauconnier
# albert gleizes
# jean metzinger
# academie
# palette
# chagall
# large canvases
# salon
# independants
# chagall
# 's paintings
# salon
# fiddler
# significant work
# mural music
# direct antecedent
# russian wedding
# chagall
# fiddler
# historical reference
# estonian
# edward sormus
# fund-raising events
# paris
# anatolii lunacharskii
# russian-
# parisian
# sormus
# revolution
# petersburg
# fiddler
# chagall
# m//sic
# revolution
# central figure
# fiddler
# background elements
# dominant figure
# fiddler
# notable characteristic
# entire theater-murals project
# psychic construction
# artist 's
# parisian
# life —
# andre salmon
# max jacob
# blaise cendrars
# guillaume apouinaire
# cendrars
# apouinaire
# apollinaire
# 's interest
# chagall
# painter 's
# paris
# chagall
# 's exhibition
# der sturm
# berlin
# paris
# chagall
# vitebsk
# apouinaire
# monumental pictures
# modern art
# avant-garde journals
# art movements
# chagall
# parisian
# chagall
# recent work
# paris
# window
# guggenheim
# museum 's collection
# janus-headed chagall
# 's auditorium
# i^ -+■ \
# conipton
# own poems
# your
# apouinaire
# 's poetry
# chagall
# 's painting
# small yellow heart
# janus-
# figure 's
# black heart
# chagall
# apollinaire
# homage
# apollinaire
# chagall
# cendrars
# apollinaire
# paris
# cendrars
# chagall
# 's pictures
# paris thro/igh
# window
# various snippets
# chagall
# cendrars
# 's poetry
# cendrars
# electric light bulbs
# montronge gare
# i'est
# north-south
# river boats world
# profundity
# rue
# b/tci
# i'lntransigeant
# paris-sports
# cimabue
# cendrars
# apparent logical connection
# accidental juxtaposition
# overheard conversation
# modern life
# multiple means
# apollinaire
# similar sources
# random fashion
# calligranniies
# novel arrangements
# literal pictures
# psychological difference
# intuitive spatial arrangement
# apouinaire
# 's poems
# les soirees
# pans
# chagall
# berlin.^- chagall
# 's quotation
# visual elements
# f/t/
# ://£'r parallels
# apouinaire
# verbal ones
# apouinaire
# 's defense
# tiddler.
# normal relation
# spatial logic
# unaccountable jumps
# viewers
# cubist
# space —
# real life
# words —
# geometric framework
# cubist
# blue tree
# composite figure
# fiddler
# '/s inches
# stedelijk mi/se/an
# amsterdam
# church tower
# upper part
# picture —
# congruent proportions —
# reliable type
# particular aspect
# cubism
# albert gleizes
# jean metzinger
# cubism
# tiddler
# enormous things
# infinitesimal things
# changes quantity
# fiddler
# cimabue
# italian masters
# apollinaire
# chagall
# slavic
# folk illustration
# russian woodblock prints
# avant-garde artists
# russia
# chagall
# 's paintings
# ideas underlay
# chagall
# fiddler
# paris
# cubism
# violinist
# paris
# chagall
# cubism
# large picture
# salon
# independants
# couple
# i'arbre
# couple
# tree
# adam
# adam
# cubo-futurist
# liubov
# popova
# paris
# academie
# palette
# chagall
# chagall
# cubism
# orphism
# apollinaire
# orphist
# march
# orphism
# ] unites painters
# different characters
# poetic vision
# chief exponent
# robert delaunay
# chagall
# chagall
# delaunay
# russian wife
# sonia
# dance hall
# bal buuier
# sonia delaunay
# colorful dancers
# chagall
# introduction
# jewish theater
# bright colors
# luminous effect
# chagall
# 's decision
# flat background
# theater murals
# chagall
# orphism
# pure abstraction
# subject matter
# orpheus
# art movement
# chagall
# hero 's lyre
# symbolic aspect
# orpheus
# ideal embodiment
# french poetry
# apouinaire
# orphic
# best/aire
# apollinaire
# orpheus
# raoul dufy
# mythical hero
# chagall
# 's auditorium
# eiffel tower
# egyptian
# dufy
# 's illustration
# chagall
# fiddler
# apouinaire
# 's poetry
# chagall
# 's work
# untranslatable lines
# cortege
# drunkard
# cut-off head
# sun /
# chagall
# russia
# contemporary poetry
# bella
# different type
# wedding scene
# different style
# gray drawing
# jewish marriage
# dramatic indoor scene
# stagelike space
# local town
# drama
# woman enlivens
# male reveler
# earthbound way
# dance
# chagall
# chief synagogue
# petrograd
# chagall
# 's preparatory
# secular scene
# visit
# grandparents.
# religious festivals
# feast
# tabernacles
# pi/rim
# final sketches
# purim
# baby carriage
# purim
# visit
# final sketches
# theater murals —
# introduction
# jewish theater
# petersburg
# designs —
# woman painting
# purim
# large figure
# fiddler
# plain white background
# cubist
# chagall
# russia
# own quirky details
# interior views
# unusual viewpoints
# bird's-eye view
# recognizable town
# russian avant-garde artists
# wide range
# contemporary artists
# unexpected sources
# aristarkh lentulov
# orneisme
# lentulov
# real lace
# chagall
# lacy cloth
# paper —
# theater murals
# dreatn
# guggenheim
# russia
# general interest
# cubism
# pablo picasso
# unusual textures —
# ivan aksenov
# russian monograph
# picasso
# considerable response
# chagall
# formal possibilities
# cubism
# different paintings
# apparition
# charles baudelaire
# chagall
# 's close-up
# dreamlike space
# cubistic apparition
# natan al'tman
# portrait
# anna akhmatova
# cubistic
# formal resemblance
# david shterenberg
# roll
# cubism
# shterenberg
# 's composition
# white paint
# house-painter 's
# polemical supplement
# aksenov
# picasso
# 's art
# artist 's
# russian artists
# paris
# picasso
# 's work
# dealer 's gallery
# submit work
# furthermore
# shterenberg
# ecole
# beaux-
# al'tman
# marie vasil'ev
# russian academy
# paris
# chagall
# cubist-oriented
# moscow
# picasso
# paris
# picasso
# 's work
# russia
# sergei shchukin
# picasso
# cubist
# moscow
# jewish artists
# february revolution
# jews
# remarkable collection
# gauguin
# henri matisse
# picasso
# french
# important corrective
# provincial attitude
# shterenberg
# chagall
# al'tman
# moscow
# culture
# jewish art
# international approach
# public display
# chagall
# 's murals
# chagall
# theater murals
# complete wall
# complex composition
# petrograd
# synagogue-school murals
# pictures oi
# birth
# wedding
# alternatively
# sonia delaunay
# orphist
# bal bullier
# gleizes
# metzinger
# 's book
# cubism
# itis introduct/oii
# jewish theater
# large restful surfaces
# excessive contiguity
# straight lines
# straight lines
# susan cdriiptim
# jewish marriage
# gouache
# india
# 20. $ x ^o cm
# x li
# collection
# gordaeva
# petersburg
# chagall
# 's auditorium j
# straight lines
# exact equivalence
# straight line
# cold tone
# warm tone
# chagall
# extensive surface
# twenty- six-foot-long canvas
# straight lines
# thin verticals
# picasso
# cubist
# work —
# gleizes
# metzinger
# 's —
# chagall
# great diagonals
# large triangles
# curves form segments
# straight lines
# cold tones
# movement — alien
# cubism
# orphism
# entire scheme
# chagall
# gleizes
# metzinger
# cubism
# compositional problem
# likely reason
# art
# vitebsk
# fellow- teacher 's book
# twentieth-century art
# kazimir malevich
# systems
# art
# december
# edition handmade
# school 's graphic workshop
# chagall
# april
# reasonable terms
# malevich
# nonetheless
# chagall
# 's firsthand experience ot
# full range
# modernist
# europe
# own mind
# colleague 's analysis
# cubism
# furthermore
# malevich
# extraordinary grasp ot
# cubism
# moscow
# petrograd
# suprematism
# suprematism
# black sq//are
# suprematism
# new culture
# subconscious form
# intuitive reason
# new art
# black square
# white ground
# gleizes
# metzinger
# 's phrase
# exact equivalence
# chagall
# malevich
# mural music
# small black square hovers
# right-hand edge
# left side
# complete black circle
# suprematism
# black wedgelike segment
# recent black paintings
# aleksandr rodchenko
# black
# black
# malevich
# tenth
# state exhibition
# non-objective art
# chagall
# 's comment
# recent battle
# love
# ballet dancers
# geometric forms
# malevich
# abstract forms
# white paintings
# rodchenko
# black forms
# recent astronomical events
# chagall
# parallel lines
# dancers —
# lie
# sholem aleichem evening
# ^^ m fig-
# collage
# pencil
# chagall
# jewish theater murals
# 2x 2y.p cm
# $ -ik x ii inches
# musee
# national d'art moderne
# centre georges pompidou
# paris
# susan compton
# edge hints
# traditional canopy
# jewish weddings
# furthermore
# shades ol
# wedding
# tew arcs
# similar color
# ballerina 's legs
# different ways
# chagall
# theater murals —
# love
# hasidic
# introduction
# baroque figure
# dance
# — show
# beginning work
# rodchenko
# varvara stepanova
# nineteenth
# state exhibition
# brief
# stepanova
# 's diary
# november
# chagall
# own verdict
# dancers —
# work —
# chagall
# own stylistic inventions
# constructivism
# chagall
# collage
# theater murals
# twenty-third
# state exhibition
# june
# collage elements
# russian collages
# rodchenko
# stepanova
# such flirtation
# chagall
# different ways
# general recognition
# june
# own initiative
# theater management
# jews
# expediently
# introd/zction
# jewish theater
# dual purpose
# new theater
# beciiuse
# se —
# puni
# lissitzky
# kandinskii
# chagall
# general public
# chagall
# 's theater murals
# early closeness
# evreinov
# introduction
# abstract geometric elements
# background double
# musical instruments
# angel trumpeter —
# deliberate incompleteness
# collage
# artist 's repertoire
# modern world
# socialist pageantry
# russia
# formalist
# malevich
# rodchenko
# lissitzky
# kandinskii
# chagall
# efros
# chagall
# granovskii
# everyday world
# cubist
# h\y life
# real musicians
# chagall
# right-hand section
# level —
# shakespeare
# hamlet
# hasidic
# chagall
# artist 's wife
# bella
# ida
# new world
# bottom-right corner
# witty image
# jewish villager
# unclean pig —
# rectangular picture
# chagall
# small scale
# berlin
# chagall
# permanent home
# tret'iakov
# chagall
# jewish painter
# hebrew
# hayim nakhman bialik
# new art museum
# tel aviv
# chagall
# international collection
# jewish artists
# palestine
# own museum
# biblical message
# nice
# france
# religious art
# chagall
# introduction
# thejeu'ish theater
# identity crisis
# tragic dimensions
# chagall
# pertinent references
# real world
# powerful —
# accessible —
# pure abstraction
# strict naturalistic representation
# art reflects
# gleizes
# metzinger
# henceforth
# mental life
# chagall
# 's auditorium
# notes
# alexandra shatskich
# aleksandra shatskikh
# marc chagall
# christoph vitali
# marc chagall
# years
# frankfurt
# schirn kunsthalle
# kamerny
# efros
# chagall
# 's murals
# artists
# granovsky
# tret'iakoi
# photo
# gregory veitsman
# gregory veitsman
# june
# rooms 17a
# chagall
# 's lithographs
# announcement ot
# tret'iakov
# side streets
# chagall
# vava
# nadia leger
# main gates
# service entrance
# director 's study
# rooms 17a
# chagall
# culture e. a. furtseva
# lebedev
# chagall
# repin
# short time
# kgb
# paris-match
# chagall
# personal request
# i. m. chaikov
# chagall
# berlin
# chagall
# museum photographer
# chagall
# june
# gosekt
# chagall
# french
# moscow
# russian
# chagall
# valentin serov
# chagall
# huge murals
# jewish theater
# room —
# chagall
# eyes shone
# short discussion
# brushes
# chagall
# russian
# vava
# chagall
# good artist
# russia
# lebedev
# careful official expression
# kgb
# kgb
# anti-zionist book
# chagall
# zionism.
# jewish theater
# chagall
# france
# early 1980s
# marc
# vava
# paul
# vence
# moscow
# furtseva
# culture
# soviet union
# communist government
# brief pause
# beautiful jewish culture
# perestroika
# soviet empire
# chagall
# york
# translated
# judith vowles aftenivrd
# solomon r. guggenheim
# honorary
# perpetuity solomon r. guggenheim justin k. thannhauser peggy guggenheim
# peter lawson-johnston vice-presidents
# right
# earl castle stewart wendy l-j
# mcneil robert m. gardiner
# thomas krens
# right
# earl castle stewart mary sharp cronson elaine dannheisser michel a. david-weill carlo de benedetti
# gianni de michelis robin chandler duke robert m. gardiner jacques hachuel moreno rainer heubach barbara jonas thomas krens peter lawson-johnston arthur levitt
# jr. wendy l-j
# mcneil edward h. meyer michael m. rea denise saul william a. schreyer james b. sherwood raja sidawi seymour slive peter w. stroh stephen c. swid rawleigh warner
# jr. jiirgen weber michael f. wettach donald m. wilson william t ylvisaker honorary
# claude pompidou
# ex officio roberto tronchetti provera
# emeritus thomas m. messer

# %% [markdown]
# # Step 3: Named Entity Recognition / Entity Extraction
#
# Named entity recognition (NER)is probably the first step towards information extraction that seeks to locate and classify named entities in text into pre-defined categories such as the names of persons, organizations, locations, expressions of times, quantities, monetary values, percentages, etc. NER is used in many fields in Natural Language Processing (NLP), and it can help answering many real-world questions, such as:
#
# Which companies were mentioned in the news article?
# Were specified products mentioned in complaints or reviews?
# Does the tweet contain the name of a person? Does the tweet contain this person’s location?
#
# [named entity](https://en.wikipedia.org/wiki/Named_entity) recognizer with NLTK and SpaCy, to identify the names of things, such as persons, organizations, or locations in the raw text. Let’s get started!
#
#
# ##  Entity Extraction with spaCy

# %%
# in case requirements.txt would not work
# import sys
# !{sys.executable} -m pip install spacy
# !{sys.executable} -m spacy download en

# %%
import spacy
from spacy import displacy
# import en_core_web_sm
# nlp = en_core_web_sm.load()
from spacy.lang.en import English

nlp = spacy.load("en")
doc = nlp(booktext)
print([(X.text, X.label_) for X in doc.ents])
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-16-be17eb636da0> in <module>()
# ----> 1 import spacy
#       2 from spacy import displacy
#       3 # import en_core_web_sm
#       4 # nlp = en_core_web_sm.load()
#       5 from spacy.lang.en import English
#
# /usr/local/lib/python2.7/site-packages/spacy/__init__.py in <module>()
#      18
#      19 if sys.maxunicode == 65535:
# ---> 20     raise SystemError(Errors.E130)
#      21
#      22
#
# SystemError: [E130] You are running a narrow unicode build, which is incompatible with spacy >= 2.1.0. To fix this, reinstall Python and use a wide unicode build instead. You can also rebuild Python and set the --enable-unicode=ucs4 flag.

# %%
len(doc.ents)

from collections import Counter
labels = [x.label_ for x in doc.ents]
Counter(labels)

# %%
items = [x.text for x in doc.ents]
Counter(items).most_common(3)

# %%
sentences = [x for x in doc.sents]
print(sentences[120])

# %% [markdown]
# ##  Entity Extraction with Google
# *! Paid API*

# %%
import six
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types


os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = os.path.join('.', "GoogleLocalCreds.json")
client = language.LanguageServiceClient()


if isinstance(text, six.binary_type):
    text = booktext.decode('utf-8')

# Instantiates a plain text document.
document = types.Document(
    content=text,
    type=enums.Document.Type.PLAIN_TEXT)

# Detects entities in the document. You can also analyze HTML with:
#   document.type == enums.Document.Type.HTML
entities = client.analyze_entities(document).entities

# %%
for entity in entities:
    entity_type = enums.Entity.Type(entity.type)
    print('=' * 20)
    print(u'{:<16}: {}'.format('name', entity.name))
    print(u'{:<16}: {}'.format('type', entity_type.name))
    print(u'{:<16}: {}'.format('salience', entity.salience))
    print(u'{:<16}: {}'.format('wikipedia_url',
          entity.metadata.get('wikipedia_url', '-')))
    print(u'{:<16}: {}'.format('mid', entity.metadata.get('mid', '-')))

# %% [markdown]
# # Step 4: Summarization
#
# There are two types of text summarization algorithms: *extractive* and *abstractive*.
#
#     * Extractive summarization algorithms attempt to score the phrases or sentences in a document and return only the most highly informative blocks of text.
#
#     * Abstractive text summarization actually creates new text which doesn’t exist in that form in the document. Abstractive summarization is what you might do when explaining a book you read to your friend, and it is much more difficult for a computer to do than extractive summarization.
#
#
# ### PyTeaser
#
# [PyTeaser](https://github.com/xiaoxu193/PyTeaser) is a Python implementation of the Scala project TextTeaser, which is a heuristic approach for extractive text summarization.TextTeaser associates a score with every sentence. This score is a linear combination of features extracted from that sentence. Features that TextTeaser looks at are:
#
# * titleFeature: The count of words which are common to title of the document and sentence.
# * sentenceLength: Authors of TextTeaser defined a constant “ideal” (with value 20), which represents the ideal length of the summary, in terms of number of words. sentenceLength is calculated as a normalized distance from this value.
# * sentencePosition: Normalized sentence number (position in the list of sentences).
# * keywordFrequency: Term frequency in the bag-of-words model (after removing stop words).

# %%
from pyteaser import Summarize
summaries = Summarize("Book about Chagall", booktext)
print summaries
# Out:
# [u'Therefore, Chagall meditating on his visions, Chagall the draftsman, is perceived even more sharply than Chagall the painter.', u'See Grigori Kasovsky, "Chagall and the Jewish Art Programme," in Vitali, Marc Chagall: The Russian Years ipo6-ip22, p. 57. 66.', u'It wants to produce the kernel trom which a normal Yiddish theater, Yiddish theater art in a European sense, will develop.', u'The Vilna artists have lived to see Chagall with their own eyes and to hear him speak in the international language, the Esperanto, called Jewish art. " Chagall delivered the opening address.', u'M. Chagall, "Letter to Pavel Davidovitch Ettinger 1920," in Vitali, Marc Chagall: The Russian Years lpo6~ip22, pp. 73\u201475. 71.']

# %% [markdown]
# ### Gensim
#
# [gensim.summarization module](https://radimrehurek.com/gensim/summarization/summariser.html) implements TextRank, an unsupervised algorithm based on weighted-graphs from a paper by Mihalcea et al. TextRank works as follows:
#
# * Pre-process the text: remove stop words and stem the remaining words.
# * Create a graph where vertices are sentences.
# * Connect every sentence to every other sentence by an edge. The weight of the edge is how similar the two sentences are.
# * Run the PageRank algorithm on the graph.
# * Pick the vertices(sentences) with the highest PageRank score
#
# In original TextRank the weights of an edge between two sentences is the percentage of words appearing in both of them.

# %%
from gensim.summarization.summarizer import summarize
print(summarize(booktext))
# Out:
# gensim Version: 3.4.0

# %% [markdown]
# ### LexRank (sumy)
#
# LexRank
# LexRank is an unsupervised graph based approach similar to TextRank. LexRank uses IDF-modified Cosine as the similarity measure between two sentences. This similarity is used as weight of the graph edge between two sentences. LexRank also incorporates an intelligent post-processing step which makes sure that top sentences chosen for the summary are not too similar to each other.
#
# More on LexRank Vs. TextRank can be found here.
#
# Note on running time: extremely slow

# %%
#Import library essentials
from sumy.parsers.plaintext import PlaintextParser #We're choosing a plaintext parser here, other parsers available for HTML etc.
from sumy.nlp.tokenizers import Tokenizer 
from sumy.summarizers.lex_rank import LexRankSummarizer #We're choosing Lexrank, other algorithms are also built in


# parser = PlaintextParser.from_file(file, Tokenizer("english"))
summarizer = LexRankSummarizer()

# string = unicode(raw_input(), 'utf8')
booktext_for_output = booktext.encode('utf8', 'replace')
summary = summarizer(booktext_for_output, 5) #Summarize the document with 5 sentences

for sentence in summary:
    print sentence

# %% [markdown]
# ### Luhn (sumy)
#
# It is one of the earliest suggested algorithm by the famous IBM researcher it was named after. It scores sentences based on frequency of the most important words.
#
# Note on running time: super fast

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.summarizers.luhn import LuhnSummarizer


parser = PlaintextParser.from_string(booktext,Tokenizer("english"))
summarizer_luhn = LuhnSummarizer()
summary_1 =summarizer_luhn(parser.document,2)
for sentence in summary_1:
	print(sentence)
# Out:
# Yet for the most part those various items are not depictions of individual objects in the world but represent several recognizable domains throughout Chagall's art: old Jews of the recent religious past, as seen from the distance of a secular generation; Christian officials and peasants of the village; his own, invented "Vitebsk " as the symbolic small town of a distant Jewish world; another version of "Vitebsk," with its churches symbolizing provincial Russia; animals in that world, often humanized; his child-bride Bella and loving couples; Jesus Christ as the suffering Jew; Paris with the emblematic Eiffel Tower and the window of his studio; and, later in his career, anonymous Jewish masses, crossing the Red Sea or facing the Holocaust; and the world of the Bible.
# A skillful and excellently precise brush; now fondly licking, now scratching; now bathing in the even ripple of the daubs, now scattering marvelous "Chagallian " little dots, drops and patterns, joyful and resounding, scarlet, green, yellow, leaping and coiling, like deposits of posies and Chinamen on the joyous wallpaper of our half-forgotten nursery; the surface — exquisitely worked — now rough, sometimes protruding with the bald spots of the background, sometimes swelling with layered iiills of paint; an even and smooth growing and waning of the tone, precise and finished, reminiscent of the growth of a range of sounds under the fingers of a flawless pianist; and a 1 38 Texts and Documents special soft film of velvet, or even the delicate down of a peach, lying over everything and evoking in the spectator a wish to touch and caress the painting, to feel its grain with his fingertips — this is Chagall's palette, transforming the colorful cover of his paintings into a kind of geographical relief map, where you can travel long and fruitfully, conscious that the irregularities, convexities, and concavities of every centimeter are utterly justified.

# %% [markdown]
# ### LSA (sumy)
# Based on term frequency techniques with singular value decomposition to summarize texts.
#
# Latent semantic analysis is an unsupervised method of summarization it combines term frequency techniques with singular value decomposition to summarize texts. It is one of the most recent suggested technique for summerization
#
# Note on running time: extremely slow

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.summarizers.lsa import LsaSummarizer

parser = PlaintextParser.from_string(booktext,Tokenizer("english"))
summarizer_lsa = LsaSummarizer()
summary_2 =summarizer_lsa(parser.document,2)
for sentence in summary_2:
    print(sentence)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-545a47224b3d> in <module>()
#       2 from sumy.summarizers.lsa import LsaSummarizer
#       3
# ----> 4 parser = PlaintextParser.from_string(booktext,Tokenizer("english"))
#       5 summarizer_lsa = LsaSummarizer()
#       6 summary_2 =summarizer_lsa(parser.document,2)
#
# NameError: name 'Tokenizer' is not defined

# %% [markdown]
# # Step 5: Topic Modeling
#
# It is an unsupervised approach used for finding and observing the bunch of words (called “topics”) in large clusters of texts.
#
# > * Bag of Words
# > * LDA

# %%
## Bag of words
phrases = Counter(ngrams(tokens_no_stop, 3))

for phrase, freq in phrases.most_common(20):
    print("{}\t{}".format(phrase, freq))


dictionary = gensim.corpora.Dictionary(processed_docs)
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# (u'Yiddish', u'Chamber', u'Theater')	70
# (u'Chagall', u'The', u'Russian')	39
# (u'The', u'Russian', u'Years')	38
# (u'Solomon', u'R.', u'Guggenheim')	31
# (u'Marc', u'Chagall', u'The')	30
# (u'Menakhem-Mendel', u'Lanternshooter', u'Menakhem-Mendel')	24
# (u'Bakingfish', u'Lanternshooter', u'Menakhem-Mendel')	24
# (u'State', u"Tret'iakov", u'Gallery')	24
# (u'Lanternshooter', u'Menakhem-Mendel', u'Lanternshooter')	23
# (u'``', u'Marc', u'Chagall')	23
# (u'Chagall', u"'s", u'art')	21
# (u'State', u'Jewish', u'Chamber')	19
# (u'Jewish', u'Chamber', u'Theater')	19
# (u'State', u'Yiddish', u'Chamber')	19
# (u'Texts', u'Documents', u'1')	18
# (u'Sholem', u'Aleichem', u'Evening')	17
# (u'R.', u'Guggenheim', u'Museum')	17
# (u'Vitali', u'Marc', u'Chagall')	17
# (u'Sholem', u'Aleichem', u"'s")	17
# (u'Chagall', u"'s", u'paintings')	17
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-01ec1c6bc2f8> in <module>()
#       6
#       7
# ----> 8 dictionary = gensim.corpora.Dictionary(processed_docs)
#       9 count = 0
#      10 for k, v in dictionary.iteritems():
#
# NameError: name 'gensim' is not defined

# %% [markdown]
# ### LDA for Topic Modeling
#
# *average run time*
#
#
# There are many approaches for obtaining topics from a text such as – Term Frequency and Inverse Document Frequency. NonNegative Matrix Factorization techniques. Latent Dirichlet Allocation is the most popular topic modeling technique and in this article, we will discuss the same.
#
# LDA assumes documents are produced from a mixture of topics. Those topics then generate words based on their probability distribution. Given a dataset of documents, LDA backtracks and tries to figure out what topics would create those documents in the first place.

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

doc_clean = [clean(doc).split() for doc in booktext]

# %%
# Importing Gensim
import gensim
from gensim import corpora

dictionary=corpora.Dictionary(doc_clean)
# Creating the term dictionary of our courpus, where every unique term is assigned an index. dictionary = corpora.Dictionary(doc_clean)

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# %% [markdown]
# Next step is to create an object for LDA model and train it on Document-Term matrix. The gensim module allows both LDA model estimation from a training corpus and inference of topic distribution on new, unseen documents.

# %%
# Create LDA Object
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=3, id2word = dictionary, passes=50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-2ed4d2fafa67> in <module>()
#       3
#       4 # Running and Trainign LDA model on the document term matrix.
# ----> 5 ldamodel = Lda(doc_term_matrix, num_topics=3, id2word = dictionary, passes=50)
#
# /usr/local/lib/python2.7/site-packages/gensim/models/ldamodel.pyc in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics, callbacks, dtype)
#     369         if corpus is not None:
#     370             use_numpy = self.dispatcher is not None
# --> 371             self.update(corpus, chunks_as_numpy=use_numpy)
#     372
#     373     def init_dir_prior(self, prior, name):
#
# /usr/local/lib/python2.7/site-packages/gensim/models/ldamodel.pyc in update(self, corpus, chunksize, decay, offset, passes, update_every, eval_every, iterations, gamma_threshold, chunks_as_numpy)
#     718                         pass_, chunk_no * chunksize + len(chunk), lencorpus
#     719                     )
# --> 720                     gammat = self.do_estep(chunk, other)
#     721
#     722                     if self.optimize_alpha:
#
# /usr/local/lib/python2.7/site-packages/gensim/models/ldamodel.pyc in do_estep(self, chunk, state)
#     531         if state is None:
#     532             state = self.state
# --> 533         gamma, sstats = self.inference(chunk, collect_sstats=True)
#     534         state.sstats += sstats
#     535         state.numdocs += gamma.shape[0]  # avoids calling len(chunk) on a generator
#
# /usr/local/lib/python2.7/site-packages/gensim/models/ldamodel.pyc in inference(self, chunk, collect_sstats)
#     507                 # Contribution of document d to the expected sufficient
#     508                 # statistics for the M step.
# --> 509                 sstats[:, ids] += np.outer(expElogthetad.T, cts / phinorm)
#     510
#     511         if len(chunk) > 1:
#
# KeyboardInterrupt:

# %%
print(ldamodel.print_topics(num_topics=3, num_words=3))

# %% [markdown]
# ### LDA with sklearn
#
# https://ourcodingclub.github.io/2018/12/10/topic-modelling-python.html
#
# > * tf (we chose tf as a variable name to stand for ‘term frequency’ - the frequency of each word/token in each tweet). The shape of tf tells us how many tweets we have and how many words we have that made it through our filtering process.
# > * tf_feature_names are the actual names of the tokens
#
# In tf matrix each row is a token and each column is a word. The numbers in each position tell us how many times this word appears in this tweet.
# Next we actually create the model object. Lets start by arbitrarily choosing 10 topics. We also define the random state so that this model is reproducible.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=0.9, min_df=25, token_pattern='\w+|\$[\d\.]+|\S+')
# apply transformation
tf = vectorizer.fit_transform(tokens_no_stop).toarray()

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names() 
#! ensure that it does not contain wierd characters, but at the same time keeps the length

# %%
from sklearn.decomposition import LatentDirichletAllocation

number_of_topics = 10
model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)

# %% [markdown]
# **model** is our LDA algorithm model object. I expect that if you are here then you should be comfortable with Python’s object orientation. If not then all you need to know is that the model object hold everything we need. It holds parameters like the number of topics that we gave it when we created it; it also holds methods like the fitting method; once we fit it, it will hold fitted parameters which tell us how important different words are in different topics. We will apply this next and feed it our tf matrix

# %%
model.fit(tf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='batch', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
#              n_components=10, n_jobs=None, n_topics=None, perp_tol=0.1,
#              random_state=0, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %% [markdown]
# Next we will want to inspect our topics that we generated and try to extract meaningful information from them.
#
# Below I have written a function which takes in our model object model, the order of the words in our matrix tf_feature_names and the number of words we would like to show. Use this function, which returns a dataframe, to show you the topics we created. Remember that each topic is a list of words/tokens and weights

# %%
no_top_words = 10
display_topics(model, tf_feature_names, no_top_words)
# Out:
#   Topic 0 weights Topic 0 words Topic 1 weights Topic 1 words Topic 2 weights  \
# 0           969.1            ''           919.1           the           194.1
# 1           594.1             .           324.1         world           176.1
# 2           327.1           new           163.1        artist           140.1
# 3           224.1             n           143.1            us           125.1
# 4           200.1            't           141.1         state           110.1
# 5           159.1         years            74.1      aleichem            96.1
# 6           151.1             p            67.1           cat            89.1
# 7           116.1             1            62.1       several            85.1
# 8           111.1       vitebsk            60.1        soviet            64.1
# 9            96.1           yet            58.1         every            61.1
#
#   Topic 2 words Topic 3 weights Topic 3 words Topic 4 weights Topic 4 words  \
# 0            he          1062.1            ``          1198.1       chagall
# 1      painting           994.1            's           678.1       replace
# 2         paris           372.1       russian           565.1        jewish
# 3      language           212.1             a           104.1            we
# 4             -           159.1          jews            91.1          many
# 5            my           154.1          marc            79.1            to
# 6         great           106.1        museum            77.1    literature
# 7         texts           104.1         could            69.1         green
# 8         later            88.1        russia            65.1      cultural
# 9         human            63.1          what            58.1        french
#
#   Topic 5 weights Topic 5 words Topic 6 weights Topic 6 words Topic 7 weights  \
# 0           805.1       theater           339.1            in           566.1
# 1           202.1        moscow           205.1           and           219.1
# 2           174.1         first           188.1          time           161.1
# 3           160.1          also           188.1          like            99.1
# 4           132.1           may           185.1    granovskii            95.1
# 5           119.1       chamber           163.1           see            66.1
# 6            99.1           for           153.1     paintings            61.1
# 7            96.1           old            89.1         whole            60.1
# 8            90.1      menakhem            79.1       painted            60.1
# 9            88.1         color            75.1          must            54.1
#
#   Topic 7 words Topic 8 weights Topic 8 words Topic 9 weights Topic 9 words
# 0           art           598.1       yiddish           835.1             i
# 1          life           304.1           one           195.1          work
# 2           but           178.1         stage           170.1            it
# 3       figures           167.1        people           167.1         would
# 4    revolution           146.1           two           147.1          even
# 5          thus           124.1       culture           124.1          this
# 6          left           123.1        murals           120.1      mikhoels
# 7         still           120.1            ot           115.1          york
# 8      national           103.1       artists            84.1        actors
# 9          book            88.1            pp            80.1          love

# %% [markdown]
# Now we have some topics, which are just clusters of words, we can try to figure out what they really mean.

# %% [markdown]
# ### PYLDAData Viz

# %%
dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
corpus = pickle.load(open('corpus.pkl', 'rb'))
lda = gensim.models.ldamodel.LdaModel.load('model5.gensim')
import pyLDAvis.gensim
lda_display = pyLDAvis.gensim.prepare(lda, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-79-9b515f9859ab> in <module>()
# ----> 1 dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
#       2 corpus = pickle.load(open('corpus.pkl', 'rb'))
#       3 lda = gensim.models.ldamodel.LdaModel.load('model5.gensim')
#       4 import pyLDAvis.gensim
#       5 lda_display = pyLDAvis.gensim.prepare(lda, corpus, dictionary, sort_topics=False)
#
# /usr/local/lib/python2.7/site-packages/gensim/utils.pyc in load(cls, fname, mmap)
#     423         compress, subname = SaveLoad._adapt_by_suffix(fname)
#     424
# --> 425         obj = unpickle(fname)
#     426         obj._load_specials(fname, mmap, compress, subname)
#     427         logger.info("loaded %s", fname)
#
# /usr/local/lib/python2.7/site-packages/gensim/utils.pyc in unpickle(fname)
#    1327
#    1328     """
# -> 1329     with smart_open(fname, 'rb') as f:
#    1330         # Because of loading from S3 load can't be used (missing readline in smart_open)
#    1331         if sys.version_info > (3, 0):
#
# /usr/local/lib/python2.7/site-packages/smart_open/smart_open_lib.pyc in smart_open(uri, mode, **kw)
#     437             transport_params[key] = value
#     438
# --> 439     return open(uri, mode, ignore_ext=ignore_extension, transport_params=transport_params, **scrubbed_kwargs)
#     440
#     441
#
# /usr/local/lib/python2.7/site-packages/smart_open/smart_open_lib.pyc in open(uri, mode, buffering, encoding, errors, newline, closefd, opener, ignore_ext, transport_params)
#     305         buffering=buffering,
#     306         encoding=encoding,
# --> 307         errors=errors,
#     308     )
#     309     if fobj is not None:
#
# /usr/local/lib/python2.7/site-packages/smart_open/smart_open_lib.pyc in _shortcut_open(uri, mode, ignore_ext, buffering, encoding, errors)
#     498         return _builtin_open(parsed_uri.uri_path, mode, buffering=buffering, **open_kwargs)
#     499     elif not open_kwargs:
# --> 500         return _builtin_open(parsed_uri.uri_path, mode, buffering=buffering)
#     501     return io.open(parsed_uri.uri_path, mode, buffering=buffering, **open_kwargs)
#     502
#
# IOError: [Errno 2] No such file or directory: 'dictionary.gensim'
